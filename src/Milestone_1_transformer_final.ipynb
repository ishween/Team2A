# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
import os
from sentence_transformers import SentenceTransformer
import chromadb
from chromadb.utils import embedding_functions

# %%
curr_dir  = os.getcwd()
data_path = os.path.join(curr_dir, "..", "data")
df = pd.read_csv(os.path.join(data_path, "processed", "original_merged_data.csv"))

# %%
df
# Out:
#      opportunity_id        sales_agent         product  account   deal_stage  \
# 0          1C1I7A6R        Moses Frase  GTX Plus Basic  Cancity          Won
# 1          Z063OYW0    Darcel Schlecht         GTX Pro    Isdom          Won
# 2          EC4QE1BX    Darcel Schlecht      MG Special  Cancity          Won
# 3          MV1LWRNH        Moses Frase       GTX Basic  Codehow          Won
# 4          PE84CX4O          Zane Levy       GTX Basic   Hatfan          Won
# ...             ...                ...             ...      ...          ...
# 8795       9MIWFW5J  Versie Hillebrand     MG Advanced      NaN  Prospecting
# 8796       6SLKZ8FI  Versie Hillebrand     MG Advanced      NaN  Prospecting
# 8797       LIB4KUZJ  Versie Hillebrand     MG Advanced      NaN  Prospecting
# 8798       18IUIUK0  Versie Hillebrand     MG Advanced      NaN  Prospecting
# 8799       8I5ONXJX  Versie Hillebrand     MG Advanced      NaN  Prospecting
#
#      engage_date  close_date  close_value           manager regional_office  \
# 0     2016-10-20  2017-03-01       1054.0  Dustin Brinkmann         Central
# 1     2016-10-25  2017-03-11       4514.0     Melvin Marxen         Central
# 2     2016-10-25  2017-03-07         50.0     Melvin Marxen         Central
# 3     2016-10-25  2017-03-09        588.0  Dustin Brinkmann         Central
# 4     2016-10-25  2017-03-02        517.0     Summer Sewald            West
# ...          ...         ...          ...               ...             ...
# 8795         NaN         NaN          NaN  Dustin Brinkmann         Central
# 8796         NaN         NaN          NaN  Dustin Brinkmann         Central
# 8797         NaN         NaN          NaN  Dustin Brinkmann         Central
# 8798         NaN         NaN          NaN  Dustin Brinkmann         Central
# 8799         NaN         NaN          NaN  Dustin Brinkmann         Central
#
#      series  sales_price    sector  year_established  revenue  employees  \
# 0       GTX         1096    retail            2001.0   718.62     2448.0
# 1       GTX         4821   medical            2002.0  3178.24     4540.0
# 2        MG           55    retail            2001.0   718.62     2448.0
# 3       GTX          550  software            1998.0  2714.90     2641.0
# 4       GTX          550  services            1982.0   792.46     1299.0
# ...     ...          ...       ...               ...      ...        ...
# 8795     MG         3393       NaN               NaN      NaN        NaN
# 8796     MG         3393       NaN               NaN      NaN        NaN
# 8797     MG         3393       NaN               NaN      NaN        NaN
# 8798     MG         3393       NaN               NaN      NaN        NaN
# 8799     MG         3393       NaN               NaN      NaN        NaN
#
#      office_location     subsidiary_of
# 0      United States               NaN
# 1      United States               NaN
# 2      United States               NaN
# 3      United States  Acme Corporation
# 4      United States               NaN
# ...              ...               ...
# 8795             NaN               NaN
# 8796             NaN               NaN
# 8797             NaN               NaN
# 8798             NaN               NaN
# 8799             NaN               NaN
#
# [8800 rows x 18 columns]

# %%
# replace every row with a sentence describing the row so that LLMs can understand it, change the sentence structure if missing values
def row_to_sentence(row):
    if pd.isna(row["deal_stage"]):
        deal_text = "The deal was at an unknown stage"
    elif row["deal_stage"] in ["Won", "Lost"]:
        deal_text = (
            f"The deal was {row['deal_stage']} "
            f"with a close value of "
            f"{'an unknown value' if pd.isna(row['close_value']) else row['close_value']}, "
            f"engaged on "
            f"{'an unknown date' if pd.isna(row['engage_date']) else pd.to_datetime(row['engage_date']).strftime('%B %d, %Y')} "
            f"and closed on "
            f"{'an unknown date' if pd.isna(row['close_date']) else pd.to_datetime(row['close_date']).strftime('%B %d, %Y')}"
        )
    elif row["deal_stage"] in ["Prospecting", "Engaging"]:
        deal_text = f"The deal is currently in the {row['deal_stage']} stage"
    else:
        deal_text = f"The deal was {row['deal_stage']}"

    return (
        f"Opportunity {'with unknown ID' if pd.isna(row['opportunity_id']) else f"with ID {row['opportunity_id']}"} for "
        f"{'an unknown account or account ID' if pd.isna(row['account']) else f"account {row['account']}"} "
        f"in {'an unknown sector' if pd.isna(row['sector']) else f"sector {row['sector']}"}, which was"
        f" established in {'an unknown year' if pd.isna(row['year_established']) else int(row['year_established'])} "
        f"with {'an unknown number of' if pd.isna(row['employees']) else int(row['employees'])} employees "
        f"and has {'an unknown revenue' if pd.isna(row['revenue']) else f'revenue of {row["revenue"]}'}."
        f" {'An unknown sales agent' if pd.isna(row['sales_agent']) else f'The sales agent {row["sales_agent"]}'}"
        f", managed by {'an unknown manager' if pd.isna(row['manager']) else row['manager']}, "
        f"handled {'an unknown product' if pd.isna(row['product']) else f'product {row['product']}'} "
        f"({'an unknown series' if pd.isna(row['series']) else f'series {row['series']}'}) "
        f"{'with an unknown price' if pd.isna(row['sales_price']) else f'priced at {row['sales_price']}'}. "
        f"{deal_text} "
        f"through {'an unknown Salesforce office' if pd.isna(row['regional_office']) else f"the {row['regional_office']} regional Salesforce office" } "
        f"located in {'an unknown location' if pd.isna(row['office_location']) else row['office_location']}."
    )

# chromaDB requires a list of IDS
def get_ids(df):
    return df['opportunity_id'].unique().tolist()

# %%
# obtain every sentence
sentences = [row_to_sentence(row) for _, row in df.iterrows()]

# %%
# prepare metadata for chromaDB
metadata = df.to_dict(orient="records")

# %%
ids = get_ids(df)

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")
embeddings = model.encode(sentences)
# print(embeddings.shape)
# print(embeddings)
# similarities = model.similarity(embeddings, embeddings)
# print(similarities)

# %%
print(f"Embedding size: {len(embeddings)}, metadata size: {len(metadata)}, sentence size: {len(sentences)}, id size: {len(ids)}")
# Out:
# Embedding size: 8800, metadata size: 8800, sentence size: 8800, id size: 8800

# %%
# create chromadb client
client = chromadb.Client()
collection = client.get_or_create_collection("sales_opportunities")

# %%
# batch them because chromadb has limit on how many you can add at once
batch_size = 5000
for i in range(0, len(embeddings), batch_size):
    batch_ids = ids[i:i+batch_size]
    batch_embeddings = embeddings[i:i+batch_size].tolist()
    batch_sentences = sentences[i:i+batch_size]
    batch_metadata = metadata[i:i+batch_size]

collection.add(
        ids=batch_ids,
        embeddings=batch_embeddings,
        documents=batch_sentences,
        metadatas=batch_metadata
)

# %%
query = "Deals engaged in November won by sales agent Darcel Schlecht"
query_embedding = model.encode([query])

results = collection.query(
    query_embeddings=query_embedding.tolist(),
    n_results=10
)

# %%
df[df['opportunity_id'].isin(results['ids'][0])]
# Out:
#      opportunity_id      sales_agent      product                    account  \
# 5075       JAH8NGC2   Vicki Laflamme  MG Advanced                 Xx-holding
# 5348       2K52EH11     Cassey Cress  MG Advanced  Vehement Capital Partners
# 5693       7CC4DUSQ     Elease Gluck  MG Advanced                 Fasehatice
# 5868       A7YPY8KI     Elease Gluck   MG Special                 Fasehatice
# 6793       8W35TVOQ    Hayden Neloms  MG Advanced                   Faxquote
# 7410       VB26KWQ6  Kary Hendrixson    GTX Basic                   Faxquote
# 7638       DXAO9R8N   Vicki Laflamme  MG Advanced                   Rantouch
# 8111       L11T0DYF   Vicki Laflamme  MG Advanced                   Faxquote
# 8233       7IAHPFT9   Vicki Laflamme  MG Advanced                   Faxquote
# 8250       HNCSYU4T   Markita Hansen  MG Advanced                   Faxquote
#
#      deal_stage engage_date  close_date  close_value        manager  \
# 5075        Won  2017-07-21  2017-09-24       2851.0   Celia Rouche
# 5348       Lost  2017-07-27  2017-12-12          0.0  Rocco Neubert
# 5693       Lost  2017-08-05  2017-11-29          0.0   Celia Rouche
# 5868        Won  2017-08-12  2017-08-21         53.0   Celia Rouche
# 6793        Won  2017-09-18  2017-12-02       2918.0   Celia Rouche
# 7410        Won  2017-10-10  2017-11-20        511.0  Summer Sewald
# 7638        Won  2017-10-18  2017-10-27       3363.0   Celia Rouche
# 8111        Won  2017-11-21  2017-12-01       2590.0   Celia Rouche
# 8233        Won  2017-12-10  2017-12-18       3078.0   Celia Rouche
# 8250        Won  2017-12-13  2017-12-27       3442.0   Celia Rouche
#
#      regional_office series  sales_price              sector  \
# 5075            West     MG         3393             finance
# 5348            East     MG         3393             finance
# 5693            West     MG         3393              retail
# 5868            West     MG           55              retail
# 6793            West     MG         3393  telecommunications
# 7410            West    GTX          550  telecommunications
# 7638            West     MG         3393  telecommunications
# 8111            West     MG         3393  telecommunications
# 8233            West     MG         3393  telecommunications
# 8250            West     MG         3393  telecommunications
#
#       year_established  revenue  employees office_location subsidiary_of
# 5075            1993.0  7537.24    20293.0   United States           NaN
# 5348            1993.0   646.10      883.0   United States       Golddex
# 5693            1990.0  4968.91     7523.0   United States           NaN
# 5868            1990.0  4968.91     7523.0   United States           NaN
# 6793            1995.0  1825.82     5595.0   United States        Sonron
# 7410            1995.0  1825.82     5595.0   United States        Sonron
# 7638            1994.0  1188.42     3015.0   United States           NaN
# 8111            1995.0  1825.82     5595.0   United States        Sonron
# 8233            1995.0  1825.82     5595.0   United States        Sonron
# 8250            1995.0  1825.82     5595.0   United States        Sonron

# %%
df[(df['deal_stage'] == 'Won') & (df['sales_agent'] == 'Darcel Schlecht')]
# Out:
#      opportunity_id      sales_agent         product  \
# 1          Z063OYW0  Darcel Schlecht         GTX Pro
# 2          EC4QE1BX  Darcel Schlecht      MG Special
# 23         ADRB8OMB  Darcel Schlecht       GTX Basic
# 41         CZVN09WN  Darcel Schlecht  GTX Plus Basic
# 45         97UN20YY  Darcel Schlecht     MG Advanced
# ...             ...              ...             ...
# 8129       K4N74V6U  Darcel Schlecht         GTX Pro
# 8139       RDZ2FC3A  Darcel Schlecht       GTX Basic
# 8155       348COZ5O  Darcel Schlecht         GTX Pro
# 8231       7GXUCFW5  Darcel Schlecht         GTX Pro
# 8253       60JGDDRO  Darcel Schlecht         GTX Pro
#
#                            account deal_stage engage_date  close_date  \
# 1                            Isdom        Won  2016-10-25  2017-03-11
# 2                          Cancity        Won  2016-10-25  2017-03-07
# 23                       Warephase        Won  2016-11-08  2017-03-26
# 41                       Konmatfix        Won  2016-11-14  2017-03-20
# 45                         Conecom        Won  2016-11-16  2017-03-14
# ...                            ...        ...         ...         ...
# 8129                       Codehow        Won  2017-11-24  2017-12-04
# 8139                     Warephase        Won  2017-11-25  2017-12-11
# 8155  Genco Pura Olive Oil Company        Won  2017-11-27  2017-11-30
# 8231                         Inity        Won  2017-12-10  2017-12-17
# 8253                       Domzoom        Won  2017-12-14  2017-12-19
#
#       close_value        manager regional_office series  sales_price  \
# 1          4514.0  Melvin Marxen         Central    GTX         4821
# 2            50.0  Melvin Marxen         Central     MG           55
# 23          561.0  Melvin Marxen         Central    GTX          550
# 41         1170.0  Melvin Marxen         Central    GTX         1096
# 45         3725.0  Melvin Marxen         Central     MG         3393
# ...           ...            ...             ...    ...          ...
# 8129       5110.0  Melvin Marxen         Central    GTX         4821
# 8139        537.0  Melvin Marxen         Central    GTX          550
# 8155       4888.0  Melvin Marxen         Central    GTX         4821
# 8231       4755.0  Melvin Marxen         Central    GTX         4821
# 8253       5052.0  Melvin Marxen         Central    GTX         4821
#
#              sector  year_established  revenue  employees office_location  \
# 1           medical            2002.0  3178.24     4540.0   United States
# 2            retail            2001.0   718.62     2448.0   United States
# 23         services            1997.0  2041.73     5276.0   United States
# 41        marketing            1985.0   375.43     1190.0   United States
# 45        technolgy            2005.0  1520.66     1806.0   United States
# ...             ...               ...      ...        ...             ...
# 8129       software            1998.0  2714.90     2641.0   United States
# 8139       services            1997.0  2041.73     5276.0   United States
# 8155         retail            2007.0   894.33     1635.0           Italy
# 8231      marketing            1986.0  2403.58     8801.0   United States
# 8253  entertainment            1998.0   217.87      551.0   United States
#
#          subsidiary_of
# 1                  NaN
# 2                  NaN
# 23                 NaN
# 41                 NaN
# 45                 NaN
# ...                ...
# 8129  Acme Corporation
# 8139               NaN
# 8155               NaN
# 8231               NaN
# 8253               NaN
#
# [349 rows x 18 columns]

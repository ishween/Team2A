# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
import os

# %%
curr_dir  = os.getcwd()
data_path = os.path.join(curr_dir, "..", "data")
df = pd.read_csv(os.path.join(data_path, "processed", "original_merged_data.csv"))

# %%
df
# Out:
#      opportunity_id        sales_agent         product  account   deal_stage  \
# 0          1C1I7A6R        Moses Frase  GTX Plus Basic  Cancity          Won
# 1          Z063OYW0    Darcel Schlecht         GTX Pro    Isdom          Won
# 2          EC4QE1BX    Darcel Schlecht      MG Special  Cancity          Won
# 3          MV1LWRNH        Moses Frase       GTX Basic  Codehow          Won
# 4          PE84CX4O          Zane Levy       GTX Basic   Hatfan          Won
# ...             ...                ...             ...      ...          ...
# 8795       9MIWFW5J  Versie Hillebrand     MG Advanced      NaN  Prospecting
# 8796       6SLKZ8FI  Versie Hillebrand     MG Advanced      NaN  Prospecting
# 8797       LIB4KUZJ  Versie Hillebrand     MG Advanced      NaN  Prospecting
# 8798       18IUIUK0  Versie Hillebrand     MG Advanced      NaN  Prospecting
# 8799       8I5ONXJX  Versie Hillebrand     MG Advanced      NaN  Prospecting
#
#      engage_date  close_date  close_value           manager regional_office  \
# 0     2016-10-20  2017-03-01       1054.0  Dustin Brinkmann         Central
# 1     2016-10-25  2017-03-11       4514.0     Melvin Marxen         Central
# 2     2016-10-25  2017-03-07         50.0     Melvin Marxen         Central
# 3     2016-10-25  2017-03-09        588.0  Dustin Brinkmann         Central
# 4     2016-10-25  2017-03-02        517.0     Summer Sewald            West
# ...          ...         ...          ...               ...             ...
# 8795         NaN         NaN          NaN  Dustin Brinkmann         Central
# 8796         NaN         NaN          NaN  Dustin Brinkmann         Central
# 8797         NaN         NaN          NaN  Dustin Brinkmann         Central
# 8798         NaN         NaN          NaN  Dustin Brinkmann         Central
# 8799         NaN         NaN          NaN  Dustin Brinkmann         Central
#
#      series  sales_price    sector  year_established  revenue  employees  \
# 0       GTX         1096    retail            2001.0   718.62     2448.0
# 1       GTX         4821   medical            2002.0  3178.24     4540.0
# 2        MG           55    retail            2001.0   718.62     2448.0
# 3       GTX          550  software            1998.0  2714.90     2641.0
# 4       GTX          550  services            1982.0   792.46     1299.0
# ...     ...          ...       ...               ...      ...        ...
# 8795     MG         3393       NaN               NaN      NaN        NaN
# 8796     MG         3393       NaN               NaN      NaN        NaN
# 8797     MG         3393       NaN               NaN      NaN        NaN
# 8798     MG         3393       NaN               NaN      NaN        NaN
# 8799     MG         3393       NaN               NaN      NaN        NaN
#
#      office_location     subsidiary_of
# 0      United States               NaN
# 1      United States               NaN
# 2      United States               NaN
# 3      United States  Acme Corporation
# 4      United States               NaN
# ...              ...               ...
# 8795             NaN               NaN
# 8796             NaN               NaN
# 8797             NaN               NaN
# 8798             NaN               NaN
# 8799             NaN               NaN
#
# [8800 rows x 18 columns]

# %%
# replace every row with a sentence describing the row so that LLMs can understand it, change the sentence structure if missing values
def row_to_sentence(row):
    if pd.isna(row["deal_stage"]):
        deal_text = "The deal was at an unknown stage"
    elif row["deal_stage"] in ["Won", "Lost"]:
        deal_text = (
            f"The deal was {row['deal_stage']} "
            f"with a close value of "
            f"{'an unknown value' if pd.isna(row['close_value']) else row['close_value']}, "
            f"engaged on "
            f"{'an unknown date' if pd.isna(row['engage_date']) else pd.to_datetime(row['engage_date']).strftime('%B %d, %Y')} "
            f"and closed on "
            f"{'an unknown date' if pd.isna(row['close_date']) else pd.to_datetime(row['close_date']).strftime('%B %d, %Y')}"
        )
    elif row["deal_stage"] in ["Prospecting", "Engaging"]:
        deal_text = f"The deal is currently in the {row['deal_stage']} stage"
    else:
        deal_text = f"The deal was {row['deal_stage']}"

    return (
        f"Opportunity {'with unknown ID' if pd.isna(row['opportunity_id']) else f"with ID {row['opportunity_id']}"} for "
        f"{'an unknown account or account ID' if pd.isna(row['account']) else f"account {row['account']}"} "
        f"in {'an unknown sector' if pd.isna(row['sector']) else f"sector {row['sector']}"}, which was"
        f" established in {'an unknown year' if pd.isna(row['year_established']) else int(row['year_established'])} "
        f"with {'an unknown number of' if pd.isna(row['employees']) else int(row['employees'])} employees "
        f"and has {'an unknown revenue' if pd.isna(row['revenue']) else f'revenue of {row["revenue"]}'}."
        f" {'An unknown sales agent' if pd.isna(row['sales_agent']) else f'The sales agent {row["sales_agent"]}'}"
        f", managed by {'an unknown manager' if pd.isna(row['manager']) else row['manager']}, "
        f"handled {'an unknown product' if pd.isna(row['product']) else f'product {row['product']}'} "
        f"({'an unknown series' if pd.isna(row['series']) else f'series {row['series']}'}) "
        f"{'with an unknown price' if pd.isna(row['sales_price']) else f'priced at {row['sales_price']}'}. "
        f"{deal_text} "
        f"through {'an unknown Salesforce office' if pd.isna(row['regional_office']) else f"the {row['regional_office']} regional Salesforce office" } "
        f"located in {'an unknown location' if pd.isna(row['office_location']) else row['office_location']}."
    )

# chromaDB requires a list of IDS
def get_ids(df):
    return df['opportunity_id'].unique().tolist()

# %%
# obtain every sentence
sentences = [row_to_sentence(row) for _, row in df.iterrows()]
sentences
# Out:
# ['Opportunity with ID 1C1I7A6R for account Cancity in sector retail, which was established in 2001 with 2448 employees and has revenue of 718.62. The sales agent Moses Frase, managed by Dustin Brinkmann, handled product GTX Plus Basic (series GTX) priced at 1096. The deal was Won with a close value of 1054.0, engaged on October 20, 2016 and closed on March 01, 2017 through the Central regional Salesforce office located in United States.',
#  'Opportunity with ID Z063OYW0 for account Isdom in sector medical, which was established in 2002 with 4540 employees and has revenue of 3178.24. The sales agent Darcel Schlecht, managed by Melvin Marxen, handled product GTX Pro (series GTX) priced at 4821. The deal was Won with a close value of 4514.0, engaged on October 25, 2016 and closed on March 11, 2017 through the Central regional Salesforce office located in United States.',
#  'Opportunity with ID EC4QE1BX for account Cancity in sector retail, which was established in 2001 with 2448 employees and has revenue of 718.62. The sales agent Darcel Schlecht, managed by Melvin Marxen, handled product MG Special (series MG) priced at 55. The deal was Won with a close value of 50.0, engaged on October 25, 2016 and closed on March 07, 2017 through the Central regional Salesforce office located in United States.',
#  'Opportunity with ID MV1LWRNH for account Codehow in sector software, which was established in 1998 with 2641 employees and has revenue of 2714.9. The sales agent Moses Frase, managed by Dustin Brinkmann, handled product GTX Basic (series GTX) priced at 550. The deal was Won with a close value of 588.0, engaged on October 25, 2016 and closed on March 09, 2017 through the Central regional Salesforce office located in United States.',
#  'Opportunity with ID PE84CX4O for account Hatfan in sector services, which was established in 1982 with 1299 employees and has revenue of 792.46. The sales agent Zane Levy, managed by Summer Sewald, handled product GTX Basic (series GTX) priced at 550. The deal was Won with a close value of 517.0, engaged on October 25, 2016 and closed on March 02, 2017 through the West regional Salesforce office located in United States.',
#  'Opportunity with ID ZNBS69V1 for account Ron-tech in sector medical, which was established in 1992 with 6837 employees and has revenue of 3922.42. The sales agent Anna Snelling, managed by Dustin Brinkmann, handled product MG Special (series MG) priced at 55. The deal was Won with a close value of 49.0, engaged on October 29, 2016 and closed on March 01, 2017 through the Central regional Salesforce office located in United States.',
#  'Opportunity with ID 9ME3374G for account J-Texon in sector retail, which was established in 1989 with 3583 employees and has revenue of 1388.67. The sales agent Vicki Laflamme, managed by Celia Rouche, handled product MG Special (series MG) priced at 55. The deal was Won with a close value of 57.0, engaged on October 30, 2016 and closed on March 02, 2017 through the West regional Salesforce office located in United States.',
#  'Opportunity with ID 7GN8Q4LL for account Cheers in sector entertainment, which was established in 1993 with 6472 employees and has revenue of 4269.9. The sales agent Markita Hansen, managed by Celia Rouche, handled product GTX Basic (series GTX) priced at 550. The deal was Won with a close value of 601.0, engaged on November 01, 2016 and closed on March 07, 2017 through the West regional Salesforce office located in United States.',
#  'Opportunity with 
 2017 through the West regional Salesforce office located in United States.',
#  'Opportunity with ID EBRWSMI0 for account Scotfind in sector software, which was established in 1996 with 16780 employees and has revenue of 6354.87. The sales agent Markita Hansen, managed by Celia Rouche, handled product GTX Plus Basic (series GTX) priced at 1096. The deal was Lost with a close value of 0.0, engaged on February 20, 2017 and closed on June 27, 2017 through the West regional Salesforce office located in United States.',
#  'Opportunity with ID 4PKHDQOQ for account Funholding in sector finance, which was established in 1991 with 7227 employees and has revenue of 2819.5. The sales agent Marty Freudenburg, managed by Melvin Marxen, handled product GTX Plus Pro (series GTX) priced at 5482. The deal was Won with a close value of 5015.0, engaged on February 20, 2017 and closed on June 03, 2017 through the Central regional Salesforce office located in United States.',
#  'Opportunity with ID 3Y9SB2QK for account Dalttechnology in sector software, which was established in 2013 with 96 employees and has revenue of 98.79. The sales agent Maureen Marcano, managed by Summer Sewald, handled product GTX Basic (series GTX) priced at 550. The deal was Won with a close value of 571.0, engaged on February 20, 2017 and closed on March 01, 2017 through the West regional Salesforce office located in United States.',
#  'Opportunity with ID 5MZ0O77T for account Bubba Gump in sector software, which was established in 2002 with 2253 employees and has revenue of 987.39. The sales agent Reed Clapper, managed by Rocco Neubert, handled product GTX Pro (series GTX) priced at 4821. The deal was Won with a close value of 4839.0, engaged on February 20, 2017 and closed on May 16, 2017 through the East regional Salesforce office located in United States.',
#  'Opportunity with ID 2EILEDKF for account Massive Dynamic in sector entertainment, which was established in 1989 with 1095 employees and has revenue of 665.06. The sales agent Reed Clapper, managed by Rocco Neubert, handled product MG Advanced (series MG) priced at 3393. The deal was Won with a close value of 3315.0, engaged on February 20, 2017 and closed on March 05, 2017 through the East regional Salesforce office located in United States.',
#  'Opportunity with ID J4NX9TK5 for account Warephase in sector services, which was established in 1997 with 5276 employees and has revenue of 2041.73. The sales agent Versie Hillebrand, managed by Dustin Brinkmann, handled product MG Special (series MG) priced at 55. The deal was Won with a close value of 60.0, engaged on February 20, 2017 and closed on May 24, 2017 through the Central regional Salesforce office located in United States.',
#  'Opportunity with ID Y7N97FW8 for an unknown account or account ID in an unknown sector, which was established in an unknown year with an unknown number of employees and has an unknown revenue. The sales agent Vicki Laflamme, managed by Celia Rouche, handled product GTX Pro (series GTX) priced at 4821. The deal is currently in the Engaging stage through the West regional Salesforce office located in an unknown location.',
#  'Opportunity with ID 0IO43YMS for an unknown account or account ID in an unknown sector, which was established in an unknown year with an unknown number of employees and has an unknown revenue. The sales agent Wilburn Farren, managed by Cara Losch, handled product MG Advanced (series MG) priced at 3393. The deal is currently in the Engaging stage through the East regional Salesforce office located in an unknown location.',
#  'Opportunity with ID 5ITSLO0E for account Treequote in sector telecommunications, which was established in 1988 with 8595 employees and has revenue of 5266.09. The sales agent Anna Snelling, managed by Dustin Brinkmann, handled product GTX Plus Basic (series GTX) priced at 1096. The deal was Won with a close value of 999.0, engaged on February 21, 2017 and closed on March 04, 2017 through the Central regional Salesforce office located in United States.',
#  'Opportunity with ID 6HG76L6U for an unknown account or account ID in an unknown sector, which was established in an unknown year with an unknown number of employees and has an unknown revenue. The sales agent Boris Faz, managed by Rocco Neubert, handled product GTX Pro (series GTX) priced at 4821. The deal is currently in the Engaging stage through the East regional Salesforce office located in an unknown location.',
#  'Opportunity with ID QGW0TI1U for account Statholdings in sector employment, which was established in 1997 with 586 employees and has revenue of 291.27. The sales agent Darcel Schlecht, managed by Melvin Marxen, handled product GTX Basic (series GTX) priced at 550. The deal was Lost with a close value of 0.0, engaged on February 21, 2017 and closed on June 11, 2017 through the Central regional Salesforce office located in United States.',
#  'Opportunity with ID WJC5J533 for account Finhigh in sector finance, which was established in 2006 with 1759 employees and has revenue of 1102.43. The sales agent Lajuana Vencill, managed by Dustin Brinkmann, handled product GTX Plus Pro (series GTX) priced at 5482. The deal was Won with a close value of 5401.0, engaged on February 21, 2017 and closed on June 04, 2017 through the Central regional Salesforce office located in United States.',
#  'Opportunity with ID 9SLINQY5 for account Newex in sector services, which was established in 1991 with 3492 employees and has revenue of 1012.72. The sales agent Markita Hansen, managed by Celia Rouche, handled product MG Advanced (series MG) priced at 3393. The deal is currently in the Engaging stage through the West regional Salesforce office located in Germany.',
#  'Opportunity with ID 1GIP77EP for an unknown account or account ID in an unknown sector, which was established in an unknown year with an unknown number of employees and has an unknown revenue. The sales agent Maureen Marcano, managed by Summer Sewald, handled product GTX Plus Pro (series GTX) priced at 5482. The deal is currently in the Engaging stage through the West regional Salesforce office located in an unknown location.',
#  'Opportunity with ID XGLMCTLG for account Rundofase in sector technolgy, which was established in 1983 with 1238 employees and has revenue of 1008.06. The sales agent Moses Frase, managed by Dustin Brinkmann, handled product GTX Basic (series GTX) priced at 550. The deal was Won with a close value of 551.0, engaged on February 21, 2017 and closed on June 18, 2017 through the Central regional Salesforce office located in United States.',
#  'Opportunity with ID X6RLT30X for account Mathtouch in sector marketing, which was established in 1984 with 9516 employees and has revenue of 3027.46. The sales agent Reed Clapper, managed by Rocco Neubert, handled product GTX Plus Pro (series GTX) priced at 5482. The deal was Lost with a close value of 0.0, engaged on February 21, 2017 and closed on May 23, 2017 through the East regional Salesforce office located in Jordan.',
#  'Opportunity with ID IVT0S1N1 for account Faxquote in sector telecommunications, which was established in 1995 with 5595 employees and has revenue of 1825.82. The sales agent Vicki Laflamme, managed by Celia Rouche, handled product GTX Basic (series GTX) priced at 550. The deal was Won with a close value of 600.0, engaged on February 21, 2017 and closed on March 20, 2017 through the West regional Salesforce office located in United States.',
#  'Opportunity with ID NOLCZMV6 for account Goodsilron in sector marketing, which was established in 2000 with 5107 employees and has revenue of 2952.73. The sales agent Violet Mclelland, managed by Cara Losch, handled product GTX Pro (series GTX) priced at 4821. The deal is currently in the Engaging stage through the East regional Salesforce office located in United States.',
#  'Opportunity with ID JEPGSQC9 for account Bioplex in sector medical, which was established in 1991 with 1016 employees and has revenue of 326.82. The sales agent Violet Mclelland, managed by Cara Losch, handled product GTX Plus Pro (series GTX) priced at 5482. The deal was Lost with a close value of 0.0, engaged on February 21, 2017 and closed on May 05, 2017 through the East regional Salesforce office located in United States.',
#  ...]

# %%
# prepare metadata for chromaDB
metadata = df.to_dict(orient="records")
metadata
# Out:
# [{'opportunity_id': '1C1I7A6R',
#   'sales_agent': 'Moses Frase',
#   'product': 'GTX Plus Basic',
#   'account': 'Cancity',
#   'deal_stage': 'Won',
#   'engage_date': '2016-10-20',
#   'close_date': '2017-03-01',
#   'close_value': 1054.0,
#   'manager': 'Dustin Brinkmann',
#   'regional_office': 'Central',
#   'series': 'GTX',
#   'sales_price': 1096,
#   'sector': 'retail',
#   'year_established': 2001.0,
#   'revenue': 718.62,
#   'employees': 2448.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'Z063OYW0',
#   'sales_agent': 'Darcel Schlecht',
#   'product': 'GTX Pro',
#   'account': 'Isdom',
#   'deal_stage': 'Won',
#   'engage_date': '2016-10-25',
#   'close_date': '2017-03-11',
#   'close_value': 4514.0,
#   'manager': 'Melvin Marxen',
#   'regional_office': 'Central',
#   'series': 'GTX',
#   'sales_price': 4821,
#   'sector': 'medical',
#   'year_established': 2002.0,
#   'revenue': 3178.24,
#   'employees': 4540.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'EC4QE1BX',
#   'sales_agent': 'Darcel Schlecht',
#   'product': 'MG Special',
#   'account': 'Cancity',
#   'deal_stage': 'Won',
#   'engage_date': '2016-10-25',
#   'close_date': '2017-03-07',
#   'close_value': 50.0,
#   'manager': 'Melvin Marxen',
#   'regional_office': 'Central',
#   'series': 'MG',
#   'sales_price': 55,
#   'sector': 'retail',
#   'year_established': 2001.0,
#   'revenue': 718.62,
#   'employees': 2448.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'MV1LWRNH',
#   'sales_agent': 'Moses Frase',
#   'product': 'GTX Basic',
#   'account': 'Codehow',
#   'deal_stage': 'Won',
#   'engage_date': '2016-10-25',
#   'close_date': '2017-03-09',
#   'close_value': 588.0,
#   'manager': 'Dustin Brinkmann',
#   'regional_office': 'Central',
#   'series': 'GTX',
#   'sales_price': 550,
#   'sector': 'software',
#   'year_established': 1998.0,
#   'revenue': 2714.9,
#   'employees': 2641.0,
#   'office_location': 'United States',
#   'subsidiary_of': 'Acme Corporation'},
#  {'opportunity_id': 'PE84CX4O',
#   'sales_agent': 'Zane Levy',
#   'product': 'GTX Basic',
#   'account': 'Hatfan',
#   'deal_stage': 'Won',
#   'engage_date': '2016-10-25',
#   'close_date': '2017-03-02',
#   'close_value': 517.0,
#   'manager': 'Summer Sewald',
#   'regional_office': 'West',
#   'series': 'GTX',
#   'sales_price': 550,
#   'sector': 'services',
#   'year_established': 1982.0,
#   'revenue': 792.46,
#   'employees': 1299.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'ZNBS69V1',
#   'sales_agent': 'Anna Snelling',
#   'product': 'MG Special',
#   'account': 'Ron-tech',
#   'deal_stage': 'Won',
#   'engage_date': '2016-10-29',
#   'close_date': '2017-03-01',
#   'close_value': 49.0,
#   'manager': 'Dustin Brinkmann',
#   'regional_office': 'Central',
#   'series': 'MG',
#   'sales_price': 55,
#   'sector': 'medical',
#   'year_established': 1992.0,
#   'revenue': 3922.42,
#   'employees': 6837.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': '9ME3374G',
#   'sales_agent': 'Vicki Laflamme',
#   'product': 'MG Special',
#   'account': 'J-Texon',
#   'deal_stage': 'Won',
#   'engage_date': '2016-10-30',
#   'close_date': '2017-03-02',
#   'close_value': 57.0,
#   'manager': 'Celia Rouche',
#   'regional_office': 'West',
#   'series': 'MG',
#   'sales_price': 55,
#   'sector': 'retail',
#   'year_established': 1989.0,
#   'revenue': 1388.67,
#   'employees': 3583.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': '7GN8Q4LL',
#   'sales_agent': 'Markita Hansen',
#   'product': 'GTX Basic',
#   'account': 'Cheers',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-01',
#   'close_date': '2017-03-07',
#   'close_value': 601.0,
#   'manager': 'Celia Rouche',
#   'regional_office': 'West',
#   'series': 'GTX',
#   'sales_price': 550,
#   'sector': 'entertainment',
#   'year_established': 1993.0,
#   'revenue': 4269.9,
#   'employees': 6472.0,
#   'office_location': 'United States',
#   'subsidiary_of': 'Massive Dynamic'},
#  {'opportunity_id': 'OLK9LKZB',
#   'sales_agent': 'Niesha Huffines',
#   'product': 'GTX Plus Basic',
#   'account': 'Zumgoity',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-01',
#   'close_date': '2017-03-03',
#   'close_value': 1026.0,
#   'manager': 'Melvin Marxen',
#   'regional_office': 'Central',
#   'series': 'GTX',
#   'sales_price': 1096,
#   'sector': 'medical',
#   'year_established': 1984.0,
#   'revenue': 441.08,
#   'employees': 1210.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'HAXMC4IX',
#   'sales_agent': 'James Ascencio',
#   'product': 'MG Advanced',
#   'account': nan,
#   'deal_stage': 'Engaging',
#   'engage_date': '2016-11-03',
#   'close_date': nan,
#   'close_value': nan,
#   'manager': 'Summer Sewald',
#   'regional_office': 'West',
#   'series': 'MG',
#   'sales_price': 3393,
#   'sector': nan,
#   'year_established': nan,
#   'revenue': nan,
#   'employees': nan,
#   'office_location': nan,
#   'subsidiary_of': nan},
#  {'opportunity_id': 'NL3JZH1Z',
#   'sales_agent': 'Anna Snelling',
#   'product': 'MG Special',
#   'account': 'Bioholding',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-04',
#   'close_date': '2017-03-10',
#   'close_value': 53.0,
#   'manager': 'Dustin Brinkmann',
#   'regional_office': 'Central',
#   'series': 'MG',
#   'sales_price': 55,
#   'sector': 'medical',
#   'year_established': 2012.0,
#   'revenue': 587.34,
#   'employees': 1356.0,
#   'office_location': 'Philipines',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'KWVA7VR1',
#   'sales_agent': 'Gladys Colclough',
#   'product': 'GTX Pro',
#   'account': 'Genco Pura Olive Oil Company',
#   'deal_stage': 'Lost',
#   'engage_date': '2016-11-04',
#   'close_date': '2017-03-18',
#   'close_value': 0.0,
#   'manager': 'Melvin Marxen',
#   'regional_office': 'Central',
#   'series': 'GTX',
#   'sales_price': 4821,
#   'sector': 'retail',
#   'year_established': 2007.0,
#   'revenue': 894.33,
#   'employees': 1635.0,
#   'office_location': 'Italy',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'S8DX3XOU',
#   'sales_agent': 'James Ascencio',
#   'product': 'GTX Plus Pro',
#   'account': 'Sunnamplex',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-04',
#   'close_date': '2017-03-10',
#   'close_value': 5169.0,
#   'manager': 'Summer Sewald',
#   'regional_office': 'West',
#   'series': 'GTX',
#   'sales_price': 5482,
#   'sector': 'marketing',
#   'year_established': 2008.0,
#   'revenue': 894.37,
#   'employees': 1593.0,
#   'office_location': 'Poland',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'ENB2XD8G',
#   'sales_agent': 'Maureen Marcano',
#   'product': 'GTX Plus Pro',
#   'account': 'Sonron',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-04',
#   'close_date': '2017-03-06',
#   'close_value': 4631.0,
#   'manager': 'Summer Sewald',
#   'regional_office': 'West',
#   'series': 'GTX',
#   'sales_price': 5482,
#   'sector': 'telecommunications',
#   'year_established': 1999.0,
#   'revenue': 1699.85,
#   'employees': 5108.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': '09YE9QOV',
#   'sales_agent': 'Hayden Neloms',
#   'product': 'MG Advanced',
#   'account': 'Finjob',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-05',
#   'close_date': '2017-03-11',
#   'close_value': 3393.0,
#   'manager': 'Celia Rouche',
#   'regional_office': 'West',
#   'series': 'MG',
#   'sales_price': 3393,
#   'sector': 'employment',
#   'year_established': 1988.0,
#   'revenue': 2059.9,
#   'employees': 3644.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': '3F5MZNEH',
#   'sales_agent': 'Rosalina Dieter',
#   'product': 'MG Special',
#   'account': 'Sonron',
#   'deal_stage': 'Lost',
#   'engage_date': '2016-11-05',
#   'close_date': '2017-03-03',
#   'close_value': 0.0,
#   'manager': 'Celia Rouche',
#   'regional_office': 'West',
#   'series': 'MG',
#   'sales_price': 55,
#   'sector': 'telecommunications',
#   'year_established': 1999.0,
#   'revenue': 1699.85,
#   'employees': 5108.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'M6WEJXC0',
#   'sales_agent': 'Rosalina Dieter',
#   'product': 'MG Advanced',
#   'account': 'Scotfind',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-05',
#   'close_date': '2017-03-06',
#   'close_value': 3284.0,
#   'manager': 'Celia Rouche',
#   'regional_office': 'West',
#   'series': 'MG',
#   'sales_price': 3393,
#   'sector': 'software',
#   'year_established': 1996.0,
#   'revenue': 6354.87,
#   'employees': 16780.0,
#   'office_location': 'United States',
#   'subsidiary_of': 'Bubba Gump'},
#  {'opportunity_id': '6PTR7VBR',
#   'sales_agent': 'Versie Hillebrand',
#   'product': 'MG Special',
#   'account': 'Treequote',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-06',
#   'close_date': '2017-03-05',
#   'close_value': 61.0,
#   'manager': 'Dustin Brinkmann',
#   'regional_office': 'Central',
#   'series': 'MG',
#   'sales_price': 55,
#   'sector': 'telecommunications',
#   'year_established': 1988.0,
#   'revenue': 5266.09,
#   'employees': 8595.0,
#   'office_location': 'United States',
#   'subsidiary_of': 'Sonron'},
#  {'opportunity_id': '902REDPA',
#   'sales_agent': 'Daniell Hammack',
#   'product': 'GTX Pro',
#   'account': 'Xx-zobam',
#   'deal_stage': 'Lost',
#   'engage_date': '2016-11-07',
#   'close_date': '2017-03-09',
#   'close_value': 0.0,
#   'manager': 'Rocco Neubert',
#   'regional_office': 'East',
#   'series': 'GTX',
#   'sales_price': 4821,
#   'sector': 'entertainment',
#   'year_established': 1989.0,
#   'revenue': 3838.39,
#   'employees': 8274.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': '5J9CMGDV',
#   'sales_agent': 'Elease Gluck',
#   'product': 'MG Special',
#   'account': 'Rantouch',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-07',
#   'close_date': '2017-03-08',
#   'close_value': 46.0,
#   'manager': 'Celia Rouche',
#   'regional_office': 'West',
#   'series': 'MG',
#   'sales_price': 55,
#   'sector': 'telecommunications',
#   'year_established': 1994.0,
#   'revenue': 1188.42,
#   'employees': 3015.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'JJXRR8R6',
#   'sales_agent': 'James Ascencio',
#   'product': 'GTX Plus Pro',
#   'account': 'Fasehatice',
#   'deal_stage': 'Lost',
#   'engage_date': '2016-11-07',
#   'close_date': '2017-03-17',
#   'close_value': 0.0,
#   'manager': 'Summer Sewald',
#   'regional_office': 'West',
#   'series': 'GTX',
#   'sales_price': 5482,
#   'sector': 'retail',
#   'year_established': 1990.0,
#   'revenue': 4968.91,
#   'employees': 7523.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'WF4HA5NW',
#   'sales_agent': 'Moses Frase',
#   'product': 'MG Special',
#   'account': 'Ron-tech',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-07',
#   'close_date': '2017-03-18',
#   'close_value': 50.0,
#   'manager': 'Dustin Brinkmann',
#   'regional_office': 'Central',
#   'series': 'MG',
#   'sales_price': 55,
#   'sector': 'medical',
#   'year_established': 1992.0,
#   'revenue': 3922.42,
#   'employees': 6837.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'C5K2JP1H',
#   'sales_agent': 'Violet Mclelland',
#   'product': 'GTX Plus Basic',
#   'account': 'Vehement Capital Partners',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-07',
#   'close_date': '2017-03-11',
#   'close_value': 1014.0,
#   'manager': 'Cara Losch',
#   'regional_office': 'East',
#   'series': 'GTX',
#   'sales_price': 1096,
#   'sector': 'finance',
#   'year_established': 1993.0,
#   'revenue': 646.1,
#   'employees': 883.0,
#   'office_location': 'United States',
#   'subsidiary_of': 'Golddex'},
#  {'opportunity_id': 'ADRB8OMB',
#   'sales_agent': 'Darcel Schlecht',
#   'product': 'GTX Basic',
#   'account': 'Warephase',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-08',
#   'close_date': '2017-03-26',
#   'close_value': 561.0,
#   'manager': 'Melvin Marxen',
#   'regional_office': 'Central',
#   'series': 'GTX',
#   'sales_price': 550,
#   'sector': 'services',
#   'year_established': 1997.0,
#   'revenue': 2041.73,
#   'employees': 5276.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'SBCR987L',
#   'sales_agent': 'Kami Bicknell',
#   'product': 'GTX Basic',
#   'account': 'Zoomit',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-10',
#   'close_date': '2017-03-23',
#   'close_value': 590.0,
#   'manager': 'Summer Sewald',
#   'regional_office': 'West',
#   'series': 'GTX',
#   'sales_price': 550,
#   'sector': 'entertainment',
#   'year_established': 1992.0,
#   'revenue': 324.19,
#   'employees': 978.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'UP409DSB',
#   'sales_agent': 'Maureen Marcano',
#   'product': 'MG Advanced',
#   'account': 'Ganjaflex',
#   'deal_stage': 'Engaging',
#   'engage_date': '2016-11-10',
#   'close_date': nan,
#   'close_value': nan,
#   'manager': 'Summer Sewald',
#   'regional_office': 'West',
#   'series': 'MG',
#   'sales_price': 3393,
#   'sector': 'retail',
#   'year_established': 1995.0,
#   'revenue': 5158.71,
#   'employees': 17479.0,
#   'office_location': 'Japan',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'JSD4APT2',
#   'sales_agent': 'Versie Hillebrand',
#   'product': 'MG Special',
#   'account': 'Bioholding',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-10',
#   'close_date': '2017-03-12',
#   'close_value': 61.0,
#   'manager': 'Dustin Brinkmann',
#   'regional_office': 'Central',
#   'series': 'MG',
#   'sales_price': 55,
#   'sector': 'medical',
#   'year_established': 2012.0,
#   'revenue': 587.34,
#   'employees': 1356.0,
#   'office_location': 'Philipines',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'AO9Z2D17',
#   'sales_agent': 'Violet Mclelland',
#   'product': 'GTX Plus Pro',
#   'account': 'Xx-zobam',
#   'deal_stage': 'Lost',
#   'engage_date': '2016-11-10',
#   'close_date': '2017-03-11',
#   'close_value': 0.0,
#   'manager': 'Cara Losch',
#   'regional_office': 'East',
#   'series': 'GTX',
#   'sales_price': 5482,
#   'sector': 'entertainment',
#   'year_established': 1989.0,
#   'revenue': 3838.39,
#   'employees': 8274.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': '5M58DTJK',
#   'sales_agent': 'Elease Gluck',
#   'product': 'MG Special',
#   'account': 'Cheers',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-11',
#   'close_date': '2017-03-05',
#   'close_value': 58.0,
#   'manager': 'Celia Rouche',
#   'regional_office': 'West',
#   'series': 'MG',
#   'sales_price': 55,
#   'sector': 'entertainment',
#   'year_established': 1993.0,
#   'revenue': 4269.9,
#   'employees': 6472.0,
#   'office_location': 'United States',
#   'subsidiary_of': 'Massive Dynamic'},
#  {'opportunity_id': 'KNY1OSAB',
#   'sales_agent': 'Maureen Marcano',
#   'product': 'GTX Pro',
#   'account': 'Labdrill',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-11',
#   'close_date': '2017-03-14',
#   'close_value': 4899.0,
#   'manager': 'Summer Sewald',
#   'regional_office': 'West',
#   'series': 'GTX',
#   'sales_price': 4821,
#   'sector': 'medical',
#   'year_established': 1985.0,
#   'revenue': 2741.37,
#   'employees': 9226.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'EAZDUUM9',
#   'sales_agent': 'Rosie Papadopoulos',
#   'product': 'MG Advanced',
#   'account': 'Zotware',
#   'deal_stage': 'Lost',
#   'engage_date': '2016-11-11',
#   'close_date': '2017-03-01',
#   'close_value': 0.0,
#   'manager': 'Cara Losch',
#   'regional_office': 'East',
#   'series': 'MG',
#   'sales_price': 3393,
#   'sector': 'software',
#   'year_established': 1979.0,
#   'revenue': 4478.47,
#   'employees': 13809.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': '2STUSOFE',
#   'sales_agent': 'Versie Hillebrand',
#   'product': 'MG Special',
#   'account': 'dambase',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-11',
#   'close_date': '2017-03-03',
#   'close_value': 67.0,
#   'manager': 'Dustin Brinkmann',
#   'regional_office': 'Central',
#   'series': 'MG',
#   'sales_price': 55,
#   'sector': 'marketing',
#   'year_established': 1995.0,
#   'revenue': 2173.98,
#   'employees': 2928.0,
#   'office_location': 'United States',
#   'subsidiary_of': 'Inity'},
#  {'opportunity_id': 'JYKM0B00',
#   'sales_agent': 'James Ascencio',
#   'product': 'GTX Pro',
#   'account': 'Xx-holding',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-12',
#   'close_date': '2017-03-06',
#   'close_value': 4338.0,
#   'manager': 'Summer Sewald',
#   'regional_office': 'West',
#   'series': 'GTX',
#   'sales_price': 4821,
#   'sector': 'finance',
#   'year_established': 1993.0,
#   'revenue': 7537.24,
#   'employees': 20293.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'KU28360J',
#   'sales_agent': 'Kary Hendrixson',
#   'product': 'GTX Basic',
#   'account': 'Fasehatice',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-12',
#   'close_date': '2017-03-19',
#   'close_value': 578.0,
#   'manager': 'Summer Sewald',
#   'regional_office': 'West',
#   'series': 'GTX',
#   'sales_price': 550,
#   'sector': 'retail',
#   'year_established': 1990.0,
#   'revenue': 4968.91,
#   'employees': 7523.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'N4SD17JR',
#   'sales_agent': 'Reed Clapper',
#   'product': 'GTX Basic',
#   'account': 'Acme Corporation',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-12',
#   'close_date': '2017-03-01',
#   'close_value': 556.0,
#   'manager': 'Rocco Neubert',
#   'regional_office': 'East',
#   'series': 'GTX',
#   'sales_price': 550,
#   'sector': 'technolgy',
#   'year_established': 1996.0,
#   'revenue': 1100.04,
#   'employees': 2822.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'E67P9Y3Q',
#   'sales_agent': 'Rosalina Dieter',
#   'product': 'GTX Basic',
#   'account': 'Green-Plus',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-12',
#   'close_date': '2017-03-03',
#   'close_value': 635.0,
#   'manager': 'Celia Rouche',
#   'regional_office': 'West',
#   'series': 'GTX',
#   'sales_price': 550,
#   'sector': 'services',
#   'year_established': 2003.0,
#   'revenue': 692.19,
#   'employees': 1922.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'AT3MMVIS',
#   'sales_agent': 'Wilburn Farren',
#   'product': 'MG Advanced',
#   'account': 'The New York Inquirer',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-12',
#   'close_date': '2017-03-07',
#   'close_value': 3045.0,
#   'manager': 'Cara Losch',
#   'regional_office': 'East',
#   'series': 'MG',
#   'sales_price': 3393,
#   'sector': 'medical',
#   'year_established': 1996.0,
#   'revenue': 439.21,
#   'employees': 792.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'REJ11LRY',
#   'sales_agent': 'Garret Kinder',
#   'product': 'GTX Plus Basic',
#   'account': 'Mathtouch',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-13',
#   'close_date': '2017-03-14',
#   'close_value': 1233.0,
#   'manager': 'Cara Losch',
#   'regional_office': 'East',
#   'series': 'GTX',
#   'sales_price': 1096,
#   'sector': 'marketing',
#   'year_established': 1984.0,
#   'revenue': 3027.46,
#   'employees': 9516.0,
#   'office_location': 'Jordan',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'ERV0CAZ7',
#   'sales_agent': 'Versie Hillebrand',
#   'product': 'MG Special',
#   'account': 'Zumgoity',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-13',
#   'close_date': '2017-03-09',
#   'close_value': 60.0,
#   'manager': 'Dustin Brinkmann',
#   'regional_office': 'Central',
#   'series': 'MG',
#   'sales_price': 55,
#   'sector': 'medical',
#   'year_established': 1984.0,
#   'revenue': 441.08,
#   'employees': 1210.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': '8SOQADK7',
#   'sales_agent': 'Anna Snelling',
#   'product': 'MG Special',
#   'account': 'Gogozoom',
#   'deal_stage': 'Lost',
#   'engage_date': '2016-11-14',
#   'close_date': '2017-03-30',
#   'close_value': 0.0,
#   'manager': 'Dustin Brinkmann',
#   'regional_office': 'Central',
#   'series': 'MG',
#   'sales_price': 55,
#   'sector': 'telecommunications',
#   'year_established': 2007.0,
#   'revenue': 86.68,
#   'employees': 187.0,
#   'office_location': 'United States',
#   'subsidiary_of': 'Sonron'},
#  {'opportunity_id': 'TCHFT25B',
#   'sales_agent': 'Darcel Schlecht',
#   'product': 'GTX Basic',
#   'account': 'Stanredtax',
#   'deal_stage': 'Lost',
#   'engage_date': '2016-11-14',
#   'close_date': '2017-03-08',
#   'close_value': 0.0,
#   'manager': 'Melvin Marxen',
#   'regional_office': 'Central',
#   'series': 'GTX',
#   'sales_price': 550,
#   'sector': 'finance',
#   'year_established': 1987.0,
#   'revenue': 1698.2,
#   'employees': 3798.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'CZVN09WN',
#   'sales_agent': 'Darcel Schlecht',
#   'product': 'GTX Plus Basic',
#   'account': 'Konmatfix',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-14',
#   'close_date': '2017-03-20',
#   'close_value': 1170.0,
#   'manager': 'Melvin Marxen',
#   'regional_office': 'Central',
#   'series': 'GTX',
#   'sales_price': 1096,
#   'sector': 'marketing',
#   'year_established': 1985.0,
#   'revenue': 375.43,
#   'employees': 1190.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'EG7OFLFR',
#   'sales_agent': 'Kami Bicknell',
#   'product': 'GTX Basic',
#   'account': nan,
#   'deal_stage': 'Engaging',
#   'engage_date': '2016-11-14',
#   'close_date': nan,
#   'close_value': nan,
#   'manager': 'Summer Sewald',
#   'regional_office': 'West',
#   'series': 'GTX',
#   'sales_price': 550,
#   'sector': nan,
#   'year_established': nan,
#   'revenue': nan,
#   'employees': nan,
#   'office_location': nan,
#   'subsidiary_of': nan},
#  {'opportunity_id': '30UQWUKB',
#   'sales_agent': 'Marty Freudenburg',
#   'product': 'GTX Plus Basic',
#   'account': 'Genco Pura Olive Oil Company',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-15',
#   'close_date': '2017-03-20',
#   'close_value': 1162.0,
#   'manager': 'Melvin Marxen',
#   'regional_office': 'Central',
#   'series': 'GTX',
#   'sales_price': 1096,
#   'sector': 'retail',
#   'year_established': 2007.0,
#   'revenue': 894.33,
#   'employees': 1635.0,
#   'office_location': 'Italy',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'OLVI7L8M',
#   'sales_agent': 'Cassey Cress',
#   'product': 'GTX Pro',
#   'account': nan,
#   'deal_stage': 'Engaging',
#   'engage_date': '2016-11-16',
#   'close_date': nan,
#   'close_value': nan,
#   'manager': 'Rocco Neubert',
#   'regional_office': 'East',
#   'series': 'GTX',
#   'sales_price': 4821,
#   'sector': nan,
#   'year_established': nan,
#   'revenue': nan,
#   'employees': nan,
#   'office_location': nan,
#   'subsidiary_of': nan},
#  {'opportunity_id': '97UN20YY',
#   'sales_agent': 'Darcel Schlecht',
#   'product': 'MG Advanced',
#   'account': 'Conecom',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-16',
#   'close_date': '2017-03-14',
#   'close_value': 3725.0,
#   'manager': 'Melvin Marxen',
#   'regional_office': 'Central',
#   'series': 'MG',
#   'sales_price': 3393,
#   'sector': 'technolgy',
#   'year_established': 2005.0,
#   'revenue': 1520.66,
#   'employees': 1806.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'JXLERZ9O',
#   'sales_agent': 'Kary Hendrixson',
#   'product': 'GTX Basic',
#   'account': 'Golddex',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-16',
#   'close_date': '2017-03-31',
#   'close_value': 559.0,
#   'manager': 'Summer Sewald',
#   'regional_office': 'West',
#   'series': 'GTX',
#   'sales_price': 550,
#   'sector': 'finance',
#   'year_established': 2008.0,
#   'revenue': 52.5,
#   'employees': 165.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': '6ROE69W5',
#   'sales_agent': 'Rosalina Dieter',
#   'product': 'GTX Basic',
#   'account': 'Plexzap',
#   'deal_stage': 'Lost',
#   'engage_date': '2016-11-16',
#   'close_date': '2017-03-11',
#   'close_value': 0.0,
#   'manager': 'Celia Rouche',
#   'regional_office': 'West',
#   'series': 'GTX',
#   'sales_price': 550,
#   'sector': 'retail',
#   'year_established': 2001.0,
#   'revenue': 2437.85,
#   'employees': 4874.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': '0DFXFKT7',
#   'sales_agent': 'Darcel Schlecht',
#   'product': 'GTX Plus Basic',
#   'account': 'Rundofase',
#   'deal_stage': 'Lost',
#   'engage_date': '2016-11-17',
#   'close_date': '2017-03-21',
#   'close_value': 0.0,
#   'manager': 'Melvin Marxen',
#   'regional_office': 'Central',
#   'series': 'GTX',
#   'sales_price': 1096,
#   'sector': 'technolgy',
#   'year_established': 1983.0,
#   'revenue': 1008.06,
#   'employees': 1238.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'XKMZVSN4',
#   'sales_agent': 'James Ascencio',
#   'product': 'GTX Plus Pro',
#   'account': 'Sonron',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-17',
#   'close_date': '2017-03-05',
#   'close_value': 4667.0,
#   'manager': 'Summer Sewald',
#   'regional_office': 'West',
#   'series': 'GTX',
#   'sales_price': 5482,
#   'sector': 'telecommunications',
#   'year_established': 1999.0,
#   'revenue': 1699.85,
#   'employees': 5108.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'IU8V0BZK',
#   'sales_agent': 'Marty Freudenburg',
#   'product': 'GTX Plus Basic',
#   'account': 'Finhigh',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-17',
#   'close_date': '2017-03-17',
#   'close_value': 903.0,
#   'manager': 'Melvin Marxen',
#   'regional_office': 'Central',
#   'series': 'GTX',
#   'sales_price': 1096,
#   'sector': 'finance',
#   'year_established': 2006.0,
#   'revenue': 1102.43,
#   'employees': 1759.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'XY42936P',
#   'sales_agent': 'Maureen Marcano',
#   'product': 'GTX Plus Basic',
#   'account': 'Finjob',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-17',
#   'close_date': '2017-03-13',
#   'close_value': 1180.0,
#   'manager': 'Summer Sewald',
#   'regional_office': 'West',
#   'series': 'GTX',
#   'sales_price': 1096,
#   'sector': 'employment',
#   'year_established': 1988.0,
#   'revenue': 2059.9,
#   'employees': 3644.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'XRN54MBM',
#   'sales_agent': 'Niesha Huffines',
#   'product': 'GTX Basic',
#   'account': 'Ron-tech',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-17',
#   'close_date': '2017-03-05',
#   'close_value': 487.0,
#   'manager': 'Melvin Marxen',
#   'regional_office': 'Central',
#   'series': 'GTX',
#   'sales_price': 550,
#   'sector': 'medical',
#   'year_established': 1992.0,
#   'revenue': 3922.42,
#   'employees': 6837.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': '2V848WZD',
#   'sales_agent': 'Lajuana Vencill',
#   'product': 'MG Advanced',
#   'account': 'Stanredtax',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-18',
#   'close_date': '2017-03-04',
#   'close_value': 3180.0,
#   'manager': 'Dustin Brinkmann',
#   'regional_office': 'Central',
#   'series': 'MG',
#   'sales_price': 3393,
#   'sector': 'finance',
#   'year_established': 1987.0,
#   'revenue': 1698.2,
#   'employees': 3798.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'ONYNTUCG',
#   'sales_agent': 'Darcel Schlecht',
#   'product': 'GTX Pro',
#   'account': 'Funholding',
#   'deal_stage': 'Lost',
#   'engage_date': '2016-11-19',
#   'close_date': '2017-03-17',
#   'close_value': 0.0,
#   'manager': 'Melvin Marxen',
#   'regional_office': 'Central',
#   'series': 'GTX',
#   'sales_price': 4821,
#   'sector': 'finance',
#   'year_established': 1991.0,
#   'revenue': 2819.5,
#   'employees': 7227.0,
#   'office_location': 'United States',
#   'subsidiary_of': 'Golddex'},
#  {'opportunity_id': 'HIOHX80Y',
#   'sales_agent': 'Darcel Schlecht',
#   'product': 'MG Advanced',
#   'account': 'Gogozoom',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-19',
#   'close_date': '2017-03-18',
#   'close_value': 3563.0,
#   'manager': 'Melvin Marxen',
#   'regional_office': 'Central',
#   'series': 'MG',
#   'sales_price': 3393,
#   'sector': 'telecommunications',
#   'year_established': 2007.0,
#   'revenue': 86.68,
#   'employees': 187.0,
#   'office_location': 'United States',
#   'subsidiary_of': 'Sonron'},
#  {'opportunity_id': 'F5U1ACDD',
#   'sales_agent': 'Kami Bicknell',
#   'product': 'GTX Plus Basic',
#   'account': nan,
#   'deal_stage': 'Engaging',
#   'engage_date': '2016-11-19',
#   'close_date': nan,
#   'close_value': nan,
#   'manager': 'Summer Sewald',
#   'regional_office': 'West',
#   'series': 'GTX',
#   'sales_price': 1096,
#   'sector': nan,
#   'year_established': nan,
#   'revenue': nan,
#   'employees': nan,
#   'office_location': nan,
#   'subsidiary_of': nan},
#  {'opportunity_id': 'LPKT07PV',
#   'sales_agent': 'Boris Faz',
#   'product': 'GTX Pro',
#   'account': 'Opentech',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-20',
#   'close_date': '2017-03-23',
#   'close_value': 4704.0,
#   'manager': 'Rocco Neubert',
#   'regional_office': 'East',
#   'series': 'GTX',
#   'sales_price': 4821,
#   'sector': 'finance',
#   'year_established': 1994.0,
#   'revenue': 355.23,
#   'employees': 853.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'WPB2SLIG',
#   'sales_agent': 'Donn Cantrell',
#   'product': 'GTX Plus Pro',
#   'account': 'Silis',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-20',
#   'close_date': '2017-03-14',
#   'close_value': 5585.0,
#   'manager': 'Rocco Neubert',
#   'regional_office': 'East',
#   'series': 'GTX',
#   'sales_price': 5482,
#   'sector': 'medical',
#   'year_established': 1994.0,
#   'revenue': 2818.38,
#   'employees': 6290.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'XUSUEAV7',
#   'sales_agent': 'Elease Gluck',
#   'product': 'GTK 500',
#   'account': 'Zoomit',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-20',
#   'close_date': '2017-03-09',
#   'close_value': 25897.0,
#   'manager': 'Celia Rouche',
#   'regional_office': 'West',
#   'series': 'GTK',
#   'sales_price': 26768,
#   'sector': 'entertainment',
#   'year_established': 1992.0,
#   'revenue': 324.19,
#   'employees': 978.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'ZZY4516R',
#   'sales_agent': 'Hayden Neloms',
#   'product': 'MG Advanced',
#   'account': nan,
#   'deal_stage': 'Engaging',
#   'engage_date': '2016-11-20',
#   'close_date': nan,
#   'close_value': nan,
#   'manager': 'Celia Rouche',
#   'regional_office': 'West',
#   'series': 'MG',
#   'sales_price': 3393,
#   'sector': nan,
#   'year_established': nan,
#   'revenue': nan,
#   'employees': nan,
#   'office_location': nan,
#   'subsidiary_of': nan},
#  {'opportunity_id': '3TYPII47',
#   'sales_agent': 'Kami Bicknell',
#   'product': 'GTX Plus Basic',
#   'account': 'Goodsilron',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-20',
#   'close_date': '2017-03-03',
#   'close_value': 1207.0,
#   'manager': 'Summer Sewald',
#   'regional_office': 'West',
#   'series': 'GTX',
#   'sales_price': 1096,
#   'sector': 'marketing',
#   'year_established': 2000.0,
#   'revenue': 2952.73,
#   'employees': 5107.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': '7WAX8Z8O',
#   'sales_agent': 'Lajuana Vencill',
#   'product': 'MG Advanced',
#   'account': 'Cancity',
#   'deal_stage': 'Lost',
#   'engage_date': '2016-11-20',
#   'close_date': '2017-03-08',
#   'close_value': 0.0,
#   'manager': 'Dustin Brinkmann',
#   'regional_office': 'Central',
#   'series': 'MG',
#   'sales_price': 3393,
#   'sector': 'retail',
#   'year_established': 2001.0,
#   'revenue': 718.62,
#   'employees': 2448.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'MYDUMR3R',
#   'sales_agent': 'Lajuana Vencill',
#   'product': 'GTX Basic',
#   'account': 'Rangreen',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-20',
#   'close_date': '2017-03-04',
#   'close_value': 559.0,
#   'manager': 'Dustin Brinkmann',
#   'regional_office': 'Central',
#   'series': 'GTX',
#   'sales_price': 550,
#   'sector': 'technolgy',
#   'year_established': 1987.0,
#   'revenue': 2938.67,
#   'employees': 8775.0,
#   'office_location': 'Panama',
#   'subsidiary_of': nan},
#  {'opportunity_id': '0DRC1U9Q',
#   'sales_agent': 'Maureen Marcano',
#   'product': 'GTX Basic',
#   'account': 'Green-Plus',
#   'deal_stage': 'Engaging',
#   'engage_date': '2016-11-20',
#   'close_date': nan,
#   'close_value': nan,
#   'manager': 'Summer Sewald',
#   'regional_office': 'West',
#   'series': 'GTX',
#   'sales_price': 550,
#   'sector': 'services',
#   'year_established': 2003.0,
#   'revenue': 692.19,
#   'employees': 1922.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': '37JFKD4I',
#   'sales_agent': 'Niesha Huffines',
#   'product': 'GTX Plus Basic',
#   'account': 'dambase',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-20',
#   'close_date': '2017-03-09',
#   'close_value': 1033.0,
#   'manager': 'Melvin Marxen',
#   'regional_office': 'Central',
#   'series': 'GTX',
#   'sales_price': 1096,
#   'sector': 'marketing',
#   'year_established': 1995.0,
#   'revenue': 2173.98,
#   'employees': 2928.0,
#   'office_location': 'United States',
#   'subsidiary_of': 'Inity'},
#  {'opportunity_id': '25YKPHX8',
#   'sales_agent': 'Donn Cantrell',
#   'product': 'GTX Basic',
#   'account': 'Kan-code',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-21',
#   'close_date': '2017-03-21',
#   'close_value': 462.0,
#   'manager': 'Rocco Neubert',
#   'regional_office': 'East',
#   'series': 'GTX',
#   'sales_price': 550,
#   'sector': 'software',
#   'year_established': 1982.0,
#   'revenue': 11698.03,
#   'employees': 34288.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'BXXMA7F3',
#   'sales_agent': 'Hayden Neloms',
#   'product': 'MG Advanced',
#   'account': 'Nam-zim',
#   'deal_stage': 'Lost',
#   'engage_date': '2016-11-21',
#   'close_date': '2017-03-01',
#   'close_value': 0.0,
#   'manager': 'Celia Rouche',
#   'regional_office': 'West',
#   'series': 'MG',
#   'sales_price': 3393,
#   'sector': 'services',
#   'year_established': 1987.0,
#   'revenue': 405.59,
#   'employees': 1179.0,
#   'office_location': 'Brazil',
#   'subsidiary_of': 'Warephase'},
#  {'opportunity_id': 'GIUUTBXM',
#   'sales_agent': 'Kary Hendrixson',
#   'product': 'GTX Pro',
#   'account': 'Y-corporation',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-21',
#   'close_date': '2017-03-14',
#   'close_value': 5539.0,
#   'manager': 'Summer Sewald',
#   'regional_office': 'West',
#   'series': 'GTX',
#   'sales_price': 4821,
#   'sector': 'employment',
#   'year_established': 1983.0,
#   'revenue': 2871.35,
#   'employees': 9561.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'MFX2LR1Q',
#   'sales_agent': 'Lajuana Vencill',
#   'product': 'MG Advanced',
#   'account': 'Ron-tech',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-21',
#   'close_date': '2017-03-15',
#   'close_value': 3573.0,
#   'manager': 'Dustin Brinkmann',
#   'regional_office': 'Central',
#   'series': 'MG',
#   'sales_price': 3393,
#   'sector': 'medical',
#   'year_established': 1992.0,
#   'revenue': 3922.42,
#   'employees': 6837.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'DUHE9FLY',
#   'sales_agent': 'Marty Freudenburg',
#   'product': 'GTX Pro',
#   'account': 'Conecom',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-21',
#   'close_date': '2017-03-01',
#   'close_value': 4926.0,
#   'manager': 'Melvin Marxen',
#   'regional_office': 'Central',
#   'series': 'GTX',
#   'sales_price': 4821,
#   'sector': 'technolgy',
#   'year_established': 2005.0,
#   'revenue': 1520.66,
#   'employees': 1806.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': '96BSG7R1',
#   'sales_agent': 'Zane Levy',
#   'product': 'GTX Plus Basic',
#   'account': 'Sunnamplex',
#   'deal_stage': 'Lost',
#   'engage_date': '2016-11-21',
#   'close_date': '2017-03-17',
#   'close_value': 0.0,
#   'manager': 'Summer Sewald',
#   'regional_office': 'West',
#   'series': 'GTX',
#   'sales_price': 1096,
#   'sector': 'marketing',
#   'year_established': 2008.0,
#   'revenue': 894.37,
#   'employees': 1593.0,
#   'office_location': 'Poland',
#   'subsidiary_of': nan},
#  {'opportunity_id': '7FQMSWIX',
#   'sales_agent': 'Corliss Cosme',
#   'product': 'MG Special',
#   'account': 'Bioplex',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-22',
#   'close_date': '2017-03-04',
#   'close_value': 62.0,
#   'manager': 'Cara Losch',
#   'regional_office': 'East',
#   'series': 'MG',
#   'sales_price': 55,
#   'sector': 'medical',
#   'year_established': 1991.0,
#   'revenue': 326.82,
#   'employees': 1016.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'C20AVXN7',
#   'sales_agent': 'Darcel Schlecht',
#   'product': 'GTX Pro',
#   'account': 'Gogozoom',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-22',
#   'close_date': '2017-03-14',
#   'close_value': 4359.0,
#   'manager': 'Melvin Marxen',
#   'regional_office': 'Central',
#   'series': 'GTX',
#   'sales_price': 4821,
#   'sector': 'telecommunications',
#   'year_established': 2007.0,
#   'revenue': 86.68,
#   'employees': 187.0,
#   'office_location': 'United States',
#   'subsidiary_of': 'Sonron'},
#  {'opportunity_id': 'GS1QVWCR',
#   'sales_agent': 'Kami Bicknell',
#   'product': 'GTX Basic',
#   'account': 'Plusstrip',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-22',
#   'close_date': '2017-03-31',
#   'close_value': 566.0,
#   'manager': 'Summer Sewald',
#   'regional_office': 'West',
#   'series': 'GTX',
#   'sales_price': 550,
#   'sector': 'entertainment',
#   'year_established': 2002.0,
#   'revenue': 349.81,
#   'employees': 315.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'ZWH8FXY3',
#   'sales_agent': 'Marty Freudenburg',
#   'product': 'GTX Basic',
#   'account': 'Toughzap',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-22',
#   'close_date': '2017-03-03',
#   'close_value': 508.0,
#   'manager': 'Melvin Marxen',
#   'regional_office': 'Central',
#   'series': 'GTX',
#   'sales_price': 550,
#   'sector': 'retail',
#   'year_established': 1995.0,
#   'revenue': 332.43,
#   'employees': 799.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': '2U94Y3Q9',
#   'sales_agent': 'Rosie Papadopoulos',
#   'product': 'MG Advanced',
#   'account': 'Vehement Capital Partners',
#   'deal_stage': 'Lost',
#   'engage_date': '2016-11-22',
#   'close_date': '2017-03-20',
#   'close_value': 0.0,
#   'manager': 'Cara Losch',
#   'regional_office': 'East',
#   'series': 'MG',
#   'sales_price': 3393,
#   'sector': 'finance',
#   'year_established': 1993.0,
#   'revenue': 646.1,
#   'employees': 883.0,
#   'office_location': 'United States',
#   'subsidiary_of': 'Golddex'},
#  {'opportunity_id': 'AAR79NOO',
#   'sales_agent': 'Versie Hillebrand',
#   'product': 'MG Special',
#   'account': 'Codehow',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-22',
#   'close_date': '2017-03-11',
#   'close_value': 51.0,
#   'manager': 'Dustin Brinkmann',
#   'regional_office': 'Central',
#   'series': 'MG',
#   'sales_price': 55,
#   'sector': 'software',
#   'year_established': 1998.0,
#   'revenue': 2714.9,
#   'employees': 2641.0,
#   'office_location': 'United States',
#   'subsidiary_of': 'Acme Corporation'},
#  {'opportunity_id': 'B6B0PNR2',
#   'sales_agent': 'Vicki Laflamme',
#   'product': 'GTX Pro',
#   'account': 'Dalttechnology',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-22',
#   'close_date': '2017-03-05',
#   'close_value': 4899.0,
#   'manager': 'Celia Rouche',
#   'regional_office': 'West',
#   'series': 'GTX',
#   'sales_price': 4821,
#   'sector': 'software',
#   'year_established': 2013.0,
#   'revenue': 98.79,
#   'employees': 96.0,
#   'office_location': 'United States',
#   'subsidiary_of': 'Bubba Gump'},
#  {'opportunity_id': 'M7I5O9YU',
#   'sales_agent': 'Corliss Cosme',
#   'product': 'GTX Basic',
#   'account': 'Cheers',
#   'deal_stage': 'Engaging',
#   'engage_date': '2016-11-23',
#   'close_date': nan,
#   'close_value': nan,
#   'manager': 'Cara Losch',
#   'regional_office': 'East',
#   'series': 'GTX',
#   'sales_price': 550,
#   'sector': 'entertainment',
#   'year_established': 1993.0,
#   'revenue': 4269.9,
#   'employees': 6472.0,
#   'office_location': 'United States',
#   'subsidiary_of': 'Massive Dynamic'},
#  {'opportunity_id': 'LXZA2OSZ',
#   'sales_agent': 'Corliss Cosme',
#   'product': 'GTX Plus Pro',
#   'account': 'Ontomedia',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-23',
#   'close_date': '2017-03-03',
#   'close_value': 5790.0,
#   'manager': 'Cara Losch',
#   'regional_office': 'East',
#   'series': 'GTX',
#   'sales_price': 5482,
#   'sector': 'employment',
#   'year_established': 1997.0,
#   'revenue': 882.12,
#   'employees': 2769.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'N0ONCYVZ',
#   'sales_agent': 'Donn Cantrell',
#   'product': 'MG Special',
#   'account': 'Kinnamplus',
#   'deal_stage': 'Lost',
#   'engage_date': '2016-11-23',
#   'close_date': '2017-03-30',
#   'close_value': 0.0,
#   'manager': 'Rocco Neubert',
#   'regional_office': 'East',
#   'series': 'MG',
#   'sales_price': 55,
#   'sector': 'retail',
#   'year_established': 2004.0,
#   'revenue': 702.72,
#   'employees': 1831.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'GYB4W2AU',
#   'sales_agent': 'Elease Gluck',
#   'product': 'MG Advanced',
#   'account': nan,
#   'deal_stage': 'Engaging',
#   'engage_date': '2016-11-23',
#   'close_date': nan,
#   'close_value': nan,
#   'manager': 'Celia Rouche',
#   'regional_office': 'West',
#   'series': 'MG',
#   'sales_price': 3393,
#   'sector': nan,
#   'year_established': nan,
#   'revenue': nan,
#   'employees': nan,
#   'office_location': nan,
#   'subsidiary_of': nan},
#  {'opportunity_id': '513DPFX5',
#   'sales_agent': 'Gladys Colclough',
#   'product': 'GTX Pro',
#   'account': 'Codehow',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-23',
#   'close_date': '2017-03-03',
#   'close_value': 4438.0,
#   'manager': 'Melvin Marxen',
#   'regional_office': 'Central',
#   'series': 'GTX',
#   'sales_price': 4821,
#   'sector': 'software',
#   'year_established': 1998.0,
#   'revenue': 2714.9,
#   'employees': 2641.0,
#   'office_location': 'United States',
#   'subsidiary_of': 'Acme Corporation'},
#  {'opportunity_id': 'RU023K5W',
#   'sales_agent': 'Gladys Colclough',
#   'product': 'MG Advanced',
#   'account': 'Finhigh',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-23',
#   'close_date': '2017-03-17',
#   'close_value': 2972.0,
#   'manager': 'Melvin Marxen',
#   'regional_office': 'Central',
#   'series': 'MG',
#   'sales_price': 3393,
#   'sector': 'finance',
#   'year_established': 2006.0,
#   'revenue': 1102.43,
#   'employees': 1759.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'VDIU10RV',
#   'sales_agent': 'Markita Hansen',
#   'product': 'MG Special',
#   'account': 'Lexiqvolax',
#   'deal_stage': 'Engaging',
#   'engage_date': '2016-11-23',
#   'close_date': nan,
#   'close_value': nan,
#   'manager': 'Celia Rouche',
#   'regional_office': 'West',
#   'series': 'MG',
#   'sales_price': 55,
#   'sector': 'medical',
#   'year_established': 2004.0,
#   'revenue': 1618.89,
#   'employees': 3889.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'BZCBQ514',
#   'sales_agent': 'Markita Hansen',
#   'product': 'GTX Basic',
#   'account': 'Y-corporation',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-23',
#   'close_date': '2017-03-01',
#   'close_value': 523.0,
#   'manager': 'Celia Rouche',
#   'regional_office': 'West',
#   'series': 'GTX',
#   'sales_price': 550,
#   'sector': 'employment',
#   'year_established': 1983.0,
#   'revenue': 2871.35,
#   'employees': 9561.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'HEE6P0QH',
#   'sales_agent': 'Anna Snelling',
#   'product': 'MG Advanced',
#   'account': 'Statholdings',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-24',
#   'close_date': '2017-03-25',
#   'close_value': 3647.0,
#   'manager': 'Dustin Brinkmann',
#   'regional_office': 'Central',
#   'series': 'MG',
#   'sales_price': 3393,
#   'sector': 'employment',
#   'year_established': 1997.0,
#   'revenue': 291.27,
#   'employees': 586.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'L8CHRJ2B',
#   'sales_agent': 'Cassey Cress',
#   'product': 'MG Advanced',
#   'account': 'Umbrella Corporation',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-24',
#   'close_date': '2017-03-01',
#   'close_value': 4200.0,
#   'manager': 'Rocco Neubert',
#   'regional_office': 'East',
#   'series': 'MG',
#   'sales_price': 3393,
#   'sector': 'finance',
#   'year_established': 1998.0,
#   'revenue': 2022.14,
#   'employees': 5113.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': '579LZ3F9',
#   'sales_agent': 'Daniell Hammack',
#   'product': 'GTX Plus Basic',
#   'account': 'J-Texon',
#   'deal_stage': 'Engaging',
#   'engage_date': '2016-11-24',
#   'close_date': nan,
#   'close_value': nan,
#   'manager': 'Rocco Neubert',
#   'regional_office': 'East',
#   'series': 'GTX',
#   'sales_price': 1096,
#   'sector': 'retail',
#   'year_established': 1989.0,
#   'revenue': 1388.67,
#   'employees': 3583.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'SU8JNMP4',
#   'sales_agent': 'Kami Bicknell',
#   'product': 'GTX Plus Basic',
#   'account': 'Bubba Gump',
#   'deal_stage': 'Engaging',
#   'engage_date': '2016-11-24',
#   'close_date': nan,
#   'close_value': nan,
#   'manager': 'Summer Sewald',
#   'regional_office': 'West',
#   'series': 'GTX',
#   'sales_price': 1096,
#   'sector': 'software',
#   'year_established': 2002.0,
#   'revenue': 987.39,
#   'employees': 2253.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'V2X2KMUR',
#   'sales_agent': 'Kami Bicknell',
#   'product': 'GTX Plus Basic',
#   'account': 'Faxquote',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-24',
#   'close_date': '2017-03-28',
#   'close_value': 1059.0,
#   'manager': 'Summer Sewald',
#   'regional_office': 'West',
#   'series': 'GTX',
#   'sales_price': 1096,
#   'sector': 'telecommunications',
#   'year_established': 1995.0,
#   'revenue': 1825.82,
#   'employees': 5595.0,
#   'office_location': 'United States',
#   'subsidiary_of': 'Sonron'},
#  {'opportunity_id': 'AJIPJP75',
#   'sales_agent': 'Marty Freudenburg',
#   'product': 'GTX Plus Basic',
#   'account': 'Codehow',
#   'deal_stage': 'Lost',
#   'engage_date': '2016-11-24',
#   'close_date': '2017-03-05',
#   'close_value': 0.0,
#   'manager': 'Melvin Marxen',
#   'regional_office': 'Central',
#   'series': 'GTX',
#   'sales_price': 1096,
#   'sector': 'software',
#   'year_established': 1998.0,
#   'revenue': 2714.9,
#   'employees': 2641.0,
#   'office_location': 'United States',
#   'subsidiary_of': 'Acme Corporation'},
#  {'opportunity_id': 'NYVA2G6U',
#   'sales_agent': 'Versie Hillebrand',
#   'product': 'MG Special',
#   'account': 'Dontechi',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-24',
#   'close_date': '2017-03-02',
#   'close_value': 57.0,
#   'manager': 'Dustin Brinkmann',
#   'regional_office': 'Central',
#   'series': 'MG',
#   'sales_price': 55,
#   'sector': 'software',
#   'year_established': 1982.0,
#   'revenue': 4618.0,
#   'employees': 10083.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'FF45BXTL',
#   'sales_agent': 'Vicki Laflamme',
#   'product': 'MG Advanced',
#   'account': 'Konex',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-24',
#   'close_date': '2017-03-27',
#   'close_value': 3671.0,
#   'manager': 'Celia Rouche',
#   'regional_office': 'West',
#   'series': 'MG',
#   'sales_price': 3393,
#   'sector': 'technolgy',
#   'year_established': 1980.0,
#   'revenue': 7708.38,
#   'employees': 13756.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'TTA9LYBS',
#   'sales_agent': 'Anna Snelling',
#   'product': 'MG Special',
#   'account': 'Treequote',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-25',
#   'close_date': '2017-03-01',
#   'close_value': 58.0,
#   'manager': 'Dustin Brinkmann',
#   'regional_office': 'Central',
#   'series': 'MG',
#   'sales_price': 55,
#   'sector': 'telecommunications',
#   'year_established': 1988.0,
#   'revenue': 5266.09,
#   'employees': 8595.0,
#   'office_location': 'United States',
#   'subsidiary_of': 'Sonron'},
#  {'opportunity_id': 'PAGZQH8L',
#   'sales_agent': 'Cecily Lampkin',
#   'product': 'MG Advanced',
#   'account': 'Treequote',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-25',
#   'close_date': '2017-03-06',
#   'close_value': 3956.0,
#   'manager': 'Dustin Brinkmann',
#   'regional_office': 'Central',
#   'series': 'MG',
#   'sales_price': 3393,
#   'sector': 'telecommunications',
#   'year_established': 1988.0,
#   'revenue': 5266.09,
#   'employees': 8595.0,
#   'office_location': 'United States',
#   'subsidiary_of': 'Sonron'},
#  {'opportunity_id': 'J7YF6DS7',
#   'sales_agent': 'Corliss Cosme',
#   'product': 'GTX Plus Pro',
#   'account': 'Betasoloin',
#   'deal_stage': 'Won',
#   'engage_date': '2016-11-25',
#   'close_date': '2017-03-01',
#   'close_value': 5964.0,
#   'manager': 'Cara Losch',
#   'regional_office': 'East',
#   'series': 'GTX',
#   'sales_price': 5482,
# ...
#   'account': 'Kan-code',
#   'deal_stage': 'Lost',
#   'engage_date': '2017-02-19',
#   'close_date': '2017-03-07',
#   'close_value': 0.0,
#   'manager': 'Celia Rouche',
#   'regional_office': 'West',
#   'series': 'GTX',
#   'sales_price': 1096,
#   'sector': 'software',
#   'year_established': 1982.0,
#   'revenue': 11698.03,
#   'employees': 34288.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'QCY951QA',
#   'sales_agent': 'Violet Mclelland',
#   'product': 'MG Special',
#   'account': 'Donquadtech',
#   'deal_stage': 'Won',
#   'engage_date': '2017-02-19',
#   'close_date': '2017-05-06',
#   'close_value': 51.0,
#   'manager': 'Cara Losch',
#   'regional_office': 'East',
#   'series': 'MG',
#   'sales_price': 55,
#   'sector': 'technolgy',
#   'year_established': 1992.0,
#   'revenue': 1712.68,
#   'employees': 3194.0,
#   'office_location': 'United States',
#   'subsidiary_of': 'Acme Corporation'},
#  {'opportunity_id': 'CG9VXPV1',
#   'sales_agent': 'Zane Levy',
#   'product': 'GTX Basic',
#   'account': nan,
#   'deal_stage': 'Engaging',
#   'engage_date': '2017-02-19',
#   'close_date': nan,
#   'close_value': nan,
#   'manager': 'Summer Sewald',
#   'regional_office': 'West',
#   'series': 'GTX',
#   'sales_price': 550,
#   'sector': nan,
#   'year_established': nan,
#   'revenue': nan,
#   'employees': nan,
#   'office_location': nan,
#   'subsidiary_of': nan},
#  {'opportunity_id': '09BVA55J',
#   'sales_agent': 'Zane Levy',
#   'product': 'GTX Basic',
#   'account': 'Scotfind',
#   'deal_stage': 'Won',
#   'engage_date': '2017-02-19',
#   'close_date': '2017-06-25',
#   'close_value': 598.0,
#   'manager': 'Summer Sewald',
#   'regional_office': 'West',
#   'series': 'GTX',
#   'sales_price': 550,
#   'sector': 'software',
#   'year_established': 1996.0,
#   'revenue': 6354.87,
#   'employees': 16780.0,
#   'office_location': 'United States',
#   'subsidiary_of': 'Bubba Gump'},
#  {'opportunity_id': '2R9HXKXT',
#   'sales_agent': 'Boris Faz',
#   'product': 'GTX Plus Basic',
#   'account': 'Konex',
#   'deal_stage': 'Lost',
#   'engage_date': '2017-02-20',
#   'close_date': '2017-05-25',
#   'close_value': 0.0,
#   'manager': 'Rocco Neubert',
#   'regional_office': 'East',
#   'series': 'GTX',
#   'sales_price': 1096,
#   'sector': 'technolgy',
#   'year_established': 1980.0,
#   'revenue': 7708.38,
#   'employees': 13756.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'JLK8KCNN',
#   'sales_agent': 'Boris Faz',
#   'product': 'MG Special',
#   'account': 'Zathunicon',
#   'deal_stage': 'Won',
#   'engage_date': '2017-02-20',
#   'close_date': '2017-05-24',
#   'close_value': 42.0,
#   'manager': 'Rocco Neubert',
#   'regional_office': 'East',
#   'series': 'MG',
#   'sales_price': 55,
#   'sector': 'retail',
#   'year_established': 2010.0,
#   'revenue': 71.12,
#   'employees': 144.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'SZQUBIMH',
#   'sales_agent': 'Cassey Cress',
#   'product': 'GTX Pro',
#   'account': 'Vehement Capital Partners',
#   'deal_stage': 'Won',
#   'engage_date': '2017-02-20',
#   'close_date': '2017-06-07',
#   'close_value': 4689.0,
#   'manager': 'Rocco Neubert',
#   'regional_office': 'East',
#   'series': 'GTX',
#   'sales_price': 4821,
#   'sector': 'finance',
#   'year_established': 1993.0,
#   'revenue': 646.1,
#   'employees': 883.0,
#   'office_location': 'United States',
#   'subsidiary_of': 'Golddex'},
#  {'opportunity_id': '8ZYVKQ27',
#   'sales_agent': 'Cecily Lampkin',
#   'product': 'GTX Plus Pro',
#   'account': 'Statholdings',
#   'deal_stage': 'Won',
#   'engage_date': '2017-02-20',
#   'close_date': '2017-06-26',
#   'close_value': 5154.0,
#   'manager': 'Dustin Brinkmann',
#   'regional_office': 'Central',
#   'series': 'GTX',
#   'sales_price': 5482,
#   'sector': 'employment',
#   'year_established': 1997.0,
#   'revenue': 291.27,
#   'employees': 586.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': '25A51PWG',
#   'sales_agent': 'Darcel Schlecht',
#   'product': 'GTX Pro',
#   'account': 'Gogozoom',
#   'deal_stage': 'Lost',
#   'engage_date': '2017-02-20',
#   'close_date': '2017-05-16',
#   'close_value': 0.0,
#   'manager': 'Melvin Marxen',
#   'regional_office': 'Central',
#   'series': 'GTX',
#   'sales_price': 4821,
#   'sector': 'telecommunications',
#   'year_established': 2007.0,
#   'revenue': 86.68,
#   'employees': 187.0,
#   'office_location': 'United States',
#   'subsidiary_of': 'Sonron'},
#  {'opportunity_id': '4B4XCPHT',
#   'sales_agent': 'Donn Cantrell',
#   'product': 'GTX Pro',
#   'account': 'Zencorporation',
#   'deal_stage': 'Won',
#   'engage_date': '2017-02-20',
#   'close_date': '2017-05-05',
#   'close_value': 5010.0,
#   'manager': 'Rocco Neubert',
#   'regional_office': 'East',
#   'series': 'GTX',
#   'sales_price': 4821,
#   'sector': 'technolgy',
#   'year_established': 2011.0,
#   'revenue': 40.79,
#   'employees': 142.0,
#   'office_location': 'China',
#   'subsidiary_of': nan},
#  {'opportunity_id': '5JFOA4XC',
#   'sales_agent': 'Gladys Colclough',
#   'product': 'MG Advanced',
#   'account': 'Finhigh',
#   'deal_stage': 'Won',
#   'engage_date': '2017-02-20',
#   'close_date': '2017-06-14',
#   'close_value': 3215.0,
#   'manager': 'Melvin Marxen',
#   'regional_office': 'Central',
#   'series': 'MG',
#   'sales_price': 3393,
#   'sector': 'finance',
#   'year_established': 2006.0,
#   'revenue': 1102.43,
#   'employees': 1759.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'N5FOEJZ9',
#   'sales_agent': 'Kami Bicknell',
#   'product': 'GTX Basic',
#   'account': 'Nam-zim',
#   'deal_stage': 'Lost',
#   'engage_date': '2017-02-20',
#   'close_date': '2017-06-03',
#   'close_value': 0.0,
#   'manager': 'Summer Sewald',
#   'regional_office': 'West',
#   'series': 'GTX',
#   'sales_price': 550,
#   'sector': 'services',
#   'year_established': 1987.0,
#   'revenue': 405.59,
#   'employees': 1179.0,
#   'office_location': 'Brazil',
#   'subsidiary_of': 'Warephase'},
#  {'opportunity_id': 'CYWZJ2AI',
#   'sales_agent': 'Kary Hendrixson',
#   'product': 'GTX Plus Basic',
#   'account': 'Donquadtech',
#   'deal_stage': 'Engaging',
#   'engage_date': '2017-02-20',
#   'close_date': nan,
#   'close_value': nan,
#   'manager': 'Summer Sewald',
#   'regional_office': 'West',
#   'series': 'GTX',
#   'sales_price': 1096,
#   'sector': 'technolgy',
#   'year_established': 1992.0,
#   'revenue': 1712.68,
#   'employees': 3194.0,
#   'office_location': 'United States',
#   'subsidiary_of': 'Acme Corporation'},
#  {'opportunity_id': 'QTNPGKJ7',
#   'sales_agent': 'Kary Hendrixson',
#   'product': 'GTX Pro',
#   'account': 'Hatfan',
#   'deal_stage': 'Won',
#   'engage_date': '2017-02-20',
#   'close_date': '2017-06-26',
#   'close_value': 3169.0,
#   'manager': 'Summer Sewald',
#   'regional_office': 'West',
#   'series': 'GTX',
#   'sales_price': 4821,
#   'sector': 'services',
#   'year_established': 1982.0,
#   'revenue': 792.46,
#   'employees': 1299.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'EBRWSMI0',
#   'sales_agent': 'Markita Hansen',
#   'product': 'GTX Plus Basic',
#   'account': 'Scotfind',
#   'deal_stage': 'Lost',
#   'engage_date': '2017-02-20',
#   'close_date': '2017-06-27',
#   'close_value': 0.0,
#   'manager': 'Celia Rouche',
#   'regional_office': 'West',
#   'series': 'GTX',
#   'sales_price': 1096,
#   'sector': 'software',
#   'year_established': 1996.0,
#   'revenue': 6354.87,
#   'employees': 16780.0,
#   'office_location': 'United States',
#   'subsidiary_of': 'Bubba Gump'},
#  {'opportunity_id': '4PKHDQOQ',
#   'sales_agent': 'Marty Freudenburg',
#   'product': 'GTX Plus Pro',
#   'account': 'Funholding',
#   'deal_stage': 'Won',
#   'engage_date': '2017-02-20',
#   'close_date': '2017-06-03',
#   'close_value': 5015.0,
#   'manager': 'Melvin Marxen',
#   'regional_office': 'Central',
#   'series': 'GTX',
#   'sales_price': 5482,
#   'sector': 'finance',
#   'year_established': 1991.0,
#   'revenue': 2819.5,
#   'employees': 7227.0,
#   'office_location': 'United States',
#   'subsidiary_of': 'Golddex'},
#  {'opportunity_id': '3Y9SB2QK',
#   'sales_agent': 'Maureen Marcano',
#   'product': 'GTX Basic',
#   'account': 'Dalttechnology',
#   'deal_stage': 'Won',
#   'engage_date': '2017-02-20',
#   'close_date': '2017-03-01',
#   'close_value': 571.0,
#   'manager': 'Summer Sewald',
#   'regional_office': 'West',
#   'series': 'GTX',
#   'sales_price': 550,
#   'sector': 'software',
#   'year_established': 2013.0,
#   'revenue': 98.79,
#   'employees': 96.0,
#   'office_location': 'United States',
#   'subsidiary_of': 'Bubba Gump'},
#  {'opportunity_id': '5MZ0O77T',
#   'sales_agent': 'Reed Clapper',
#   'product': 'GTX Pro',
#   'account': 'Bubba Gump',
#   'deal_stage': 'Won',
#   'engage_date': '2017-02-20',
#   'close_date': '2017-05-16',
#   'close_value': 4839.0,
#   'manager': 'Rocco Neubert',
#   'regional_office': 'East',
#   'series': 'GTX',
#   'sales_price': 4821,
#   'sector': 'software',
#   'year_established': 2002.0,
#   'revenue': 987.39,
#   'employees': 2253.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': '2EILEDKF',
#   'sales_agent': 'Reed Clapper',
#   'product': 'MG Advanced',
#   'account': 'Massive Dynamic',
#   'deal_stage': 'Won',
#   'engage_date': '2017-02-20',
#   'close_date': '2017-03-05',
#   'close_value': 3315.0,
#   'manager': 'Rocco Neubert',
#   'regional_office': 'East',
#   'series': 'MG',
#   'sales_price': 3393,
#   'sector': 'entertainment',
#   'year_established': 1989.0,
#   'revenue': 665.06,
#   'employees': 1095.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'J4NX9TK5',
#   'sales_agent': 'Versie Hillebrand',
#   'product': 'MG Special',
#   'account': 'Warephase',
#   'deal_stage': 'Won',
#   'engage_date': '2017-02-20',
#   'close_date': '2017-05-24',
#   'close_value': 60.0,
#   'manager': 'Dustin Brinkmann',
#   'regional_office': 'Central',
#   'series': 'MG',
#   'sales_price': 55,
#   'sector': 'services',
#   'year_established': 1997.0,
#   'revenue': 2041.73,
#   'employees': 5276.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'Y7N97FW8',
#   'sales_agent': 'Vicki Laflamme',
#   'product': 'GTX Pro',
#   'account': nan,
#   'deal_stage': 'Engaging',
#   'engage_date': '2017-02-20',
#   'close_date': nan,
#   'close_value': nan,
#   'manager': 'Celia Rouche',
#   'regional_office': 'West',
#   'series': 'GTX',
#   'sales_price': 4821,
#   'sector': nan,
#   'year_established': nan,
#   'revenue': nan,
#   'employees': nan,
#   'office_location': nan,
#   'subsidiary_of': nan},
#  {'opportunity_id': '0IO43YMS',
#   'sales_agent': 'Wilburn Farren',
#   'product': 'MG Advanced',
#   'account': nan,
#   'deal_stage': 'Engaging',
#   'engage_date': '2017-02-20',
#   'close_date': nan,
#   'close_value': nan,
#   'manager': 'Cara Losch',
#   'regional_office': 'East',
#   'series': 'MG',
#   'sales_price': 3393,
#   'sector': nan,
#   'year_established': nan,
#   'revenue': nan,
#   'employees': nan,
#   'office_location': nan,
#   'subsidiary_of': nan},
#  {'opportunity_id': '5ITSLO0E',
#   'sales_agent': 'Anna Snelling',
#   'product': 'GTX Plus Basic',
#   'account': 'Treequote',
#   'deal_stage': 'Won',
#   'engage_date': '2017-02-21',
#   'close_date': '2017-03-04',
#   'close_value': 999.0,
#   'manager': 'Dustin Brinkmann',
#   'regional_office': 'Central',
#   'series': 'GTX',
#   'sales_price': 1096,
#   'sector': 'telecommunications',
#   'year_established': 1988.0,
#   'revenue': 5266.09,
#   'employees': 8595.0,
#   'office_location': 'United States',
#   'subsidiary_of': 'Sonron'},
#  {'opportunity_id': '6HG76L6U',
#   'sales_agent': 'Boris Faz',
#   'product': 'GTX Pro',
#   'account': nan,
#   'deal_stage': 'Engaging',
#   'engage_date': '2017-02-21',
#   'close_date': nan,
#   'close_value': nan,
#   'manager': 'Rocco Neubert',
#   'regional_office': 'East',
#   'series': 'GTX',
#   'sales_price': 4821,
#   'sector': nan,
#   'year_established': nan,
#   'revenue': nan,
#   'employees': nan,
#   'office_location': nan,
#   'subsidiary_of': nan},
#  {'opportunity_id': 'QGW0TI1U',
#   'sales_agent': 'Darcel Schlecht',
#   'product': 'GTX Basic',
#   'account': 'Statholdings',
#   'deal_stage': 'Lost',
#   'engage_date': '2017-02-21',
#   'close_date': '2017-06-11',
#   'close_value': 0.0,
#   'manager': 'Melvin Marxen',
#   'regional_office': 'Central',
#   'series': 'GTX',
#   'sales_price': 550,
#   'sector': 'employment',
#   'year_established': 1997.0,
#   'revenue': 291.27,
#   'employees': 586.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'WJC5J533',
#   'sales_agent': 'Lajuana Vencill',
#   'product': 'GTX Plus Pro',
#   'account': 'Finhigh',
#   'deal_stage': 'Won',
#   'engage_date': '2017-02-21',
#   'close_date': '2017-06-04',
#   'close_value': 5401.0,
#   'manager': 'Dustin Brinkmann',
#   'regional_office': 'Central',
#   'series': 'GTX',
#   'sales_price': 5482,
#   'sector': 'finance',
#   'year_established': 2006.0,
#   'revenue': 1102.43,
#   'employees': 1759.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': '9SLINQY5',
#   'sales_agent': 'Markita Hansen',
#   'product': 'MG Advanced',
#   'account': 'Newex',
#   'deal_stage': 'Engaging',
#   'engage_date': '2017-02-21',
#   'close_date': nan,
#   'close_value': nan,
#   'manager': 'Celia Rouche',
#   'regional_office': 'West',
#   'series': 'MG',
#   'sales_price': 3393,
#   'sector': 'services',
#   'year_established': 1991.0,
#   'revenue': 1012.72,
#   'employees': 3492.0,
#   'office_location': 'Germany',
#   'subsidiary_of': nan},
#  {'opportunity_id': '1GIP77EP',
#   'sales_agent': 'Maureen Marcano',
#   'product': 'GTX Plus Pro',
#   'account': nan,
#   'deal_stage': 'Engaging',
#   'engage_date': '2017-02-21',
#   'close_date': nan,
#   'close_value': nan,
#   'manager': 'Summer Sewald',
#   'regional_office': 'West',
#   'series': 'GTX',
#   'sales_price': 5482,
#   'sector': nan,
#   'year_established': nan,
#   'revenue': nan,
#   'employees': nan,
#   'office_location': nan,
#   'subsidiary_of': nan},
#  {'opportunity_id': 'XGLMCTLG',
#   'sales_agent': 'Moses Frase',
#   'product': 'GTX Basic',
#   'account': 'Rundofase',
#   'deal_stage': 'Won',
#   'engage_date': '2017-02-21',
#   'close_date': '2017-06-18',
#   'close_value': 551.0,
#   'manager': 'Dustin Brinkmann',
#   'regional_office': 'Central',
#   'series': 'GTX',
#   'sales_price': 550,
#   'sector': 'technolgy',
#   'year_established': 1983.0,
#   'revenue': 1008.06,
#   'employees': 1238.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'X6RLT30X',
#   'sales_agent': 'Reed Clapper',
#   'product': 'GTX Plus Pro',
#   'account': 'Mathtouch',
#   'deal_stage': 'Lost',
#   'engage_date': '2017-02-21',
#   'close_date': '2017-05-23',
#   'close_value': 0.0,
#   'manager': 'Rocco Neubert',
#   'regional_office': 'East',
#   'series': 'GTX',
#   'sales_price': 5482,
#   'sector': 'marketing',
#   'year_established': 1984.0,
#   'revenue': 3027.46,
#   'employees': 9516.0,
#   'office_location': 'Jordan',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'IVT0S1N1',
#   'sales_agent': 'Vicki Laflamme',
#   'product': 'GTX Basic',
#   'account': 'Faxquote',
#   'deal_stage': 'Won',
#   'engage_date': '2017-02-21',
#   'close_date': '2017-03-20',
#   'close_value': 600.0,
#   'manager': 'Celia Rouche',
#   'regional_office': 'West',
#   'series': 'GTX',
#   'sales_price': 550,
#   'sector': 'telecommunications',
#   'year_established': 1995.0,
#   'revenue': 1825.82,
#   'employees': 5595.0,
#   'office_location': 'United States',
#   'subsidiary_of': 'Sonron'},
#  {'opportunity_id': 'NOLCZMV6',
#   'sales_agent': 'Violet Mclelland',
#   'product': 'GTX Pro',
#   'account': 'Goodsilron',
#   'deal_stage': 'Engaging',
#   'engage_date': '2017-02-21',
#   'close_date': nan,
#   'close_value': nan,
#   'manager': 'Cara Losch',
#   'regional_office': 'East',
#   'series': 'GTX',
#   'sales_price': 4821,
#   'sector': 'marketing',
#   'year_established': 2000.0,
#   'revenue': 2952.73,
#   'employees': 5107.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  {'opportunity_id': 'JEPGSQC9',
#   'sales_agent': 'Violet Mclelland',
#   'product': 'GTX Plus Pro',
#   'account': 'Bioplex',
#   'deal_stage': 'Lost',
#   'engage_date': '2017-02-21',
#   'close_date': '2017-05-05',
#   'close_value': 0.0,
#   'manager': 'Cara Losch',
#   'regional_office': 'East',
#   'series': 'GTX',
#   'sales_price': 5482,
#   'sector': 'medical',
#   'year_established': 1991.0,
#   'revenue': 326.82,
#   'employees': 1016.0,
#   'office_location': 'United States',
#   'subsidiary_of': nan},
#  ...]

# %%
get_ids(df)
# Out:
# ['1C1I7A6R',
#  'Z063OYW0',
#  'EC4QE1BX',
#  'MV1LWRNH',
#  'PE84CX4O',
#  'ZNBS69V1',
#  '9ME3374G',
#  '7GN8Q4LL',
#  'OLK9LKZB',
#  'HAXMC4IX',
#  'NL3JZH1Z',
#  'KWVA7VR1',
#  'S8DX3XOU',
#  'ENB2XD8G',
#  '09YE9QOV',
#  '3F5MZNEH',
#  'M6WEJXC0',
#  '6PTR7VBR',
#  '902REDPA',
#  '5J9CMGDV',
#  'JJXRR8R6',
#  'WF4HA5NW',
#  'C5K2JP1H',
#  'ADRB8OMB',
#  'SBCR987L',
#  'UP409DSB',
#  'JSD4APT2',
#  'AO9Z2D17',
#  '5M58DTJK',
#  'KNY1OSAB',
#  'EAZDUUM9',
#  '2STUSOFE',
#  'JYKM0B00',
#  'KU28360J',
#  'N4SD17JR',
#  'E67P9Y3Q',
#  'AT3MMVIS',
#  'REJ11LRY',
#  'ERV0CAZ7',
#  '8SOQADK7',
#  'TCHFT25B',
#  'CZVN09WN',
#  'EG7OFLFR',
#  '30UQWUKB',
#  'OLVI7L8M',
#  '97UN20YY',
#  'JXLERZ9O',
#  '6ROE69W5',
#  '0DFXFKT7',
#  'XKMZVSN4',
#  'IU8V0BZK',
#  'XY42936P',
#  'XRN54MBM',
#  '2V848WZD',
#  'ONYNTUCG',
#  'HIOHX80Y',
#  'F5U1ACDD',
#  'LPKT07PV',
#  'WPB2SLIG',
#  'XUSUEAV7',
#  'ZZY4516R',
#  '3TYPII47',
#  '7WAX8Z8O',
#  'MYDUMR3R',
#  '0DRC1U9Q',
#  '37JFKD4I',
#  '25YKPHX8',
#  'BXXMA7F3',
#  'GIUUTBXM',
#  'MFX2LR1Q',
#  'DUHE9FLY',
#  '96BSG7R1',
#  '7FQMSWIX',
#  'C20AVXN7',
#  'GS1QVWCR',
#  'ZWH8FXY3',
#  '2U94Y3Q9',
#  'AAR79NOO',
#  'B6B0PNR2',
#  'M7I5O9YU',
#  'LXZA2OSZ',
#  'N0ONCYVZ',
#  'GYB4W2AU',
#  '513DPFX5',
#  'RU023K5W',
#  'VDIU10RV',
#  'BZCBQ514',
#  'HEE6P0QH',
#  'L8CHRJ2B',
#  '579LZ3F9',
#  'SU8JNMP4',
#  'V2X2KMUR',
#  'AJIPJP75',
#  'NYVA2G6U',
#  'FF45BXTL',
#  'TTA9LYBS',
#  'PAGZQH8L',
#  'J7YF6DS7',
#  'S5IXY4Z9',
#  'JQBJMETQ',
#  '0LVWSWEW',
#  'K53BC1T9',
#  'D40N5I9Y',
#  '051QTX8Z',
#  '5D2XH04S',
#  'V9E582SK',
#  'UK0LEZRJ',
#  'PFFHM7HR',
#  'IT10CFQH',
#  '8VKD2CCH',
#  '2XQAKBXH',
#  '7G7YLGJO',
#  'GCA97W27',
#  'K8FUZHOG',
#  '5WJZMULK',
#  'ZPYD4T9W',
#  'KE9ZEDS8',
#  '7KK0HQ4C',
#  'FP7014Z0',
#  'N4HFHDMW',
#  '2HFLKREC',
#  '7JVTTVCO',
#  '3X13866U',
#  '7LE19SYE',
#  'J5V2M7Y1',
#  '41MURAI5',
#  'QHI8WRIA',
#  'AJXAXV4W',
#  'VPDXX5PJ',
#  'PZB9NUK8',
#  'A0ANOYPF',
#  '0P4AAPYX',
#  'O6T5WC3W',
#  '0NO04P6C',
#  '22OFSXBT',
#  'MRXZTMM6',
#  'LGI8QEC2',
#  '6KZ0NCFX',
#  '3SF8O9S6',
#  'CNM0H9FR',
#  'XK668R7C',
#  'TZCAQWL3',
#  'BADC6A9H',
#  'B8E0UUZR',
#  'I043RXJV',
#  'MWWB44CC',
#  'HBTINPDG',
#  'DZ3KHZSX',
#  '3W1K7X5F',
#  '45A57X68',
#  '9SLYC4TR',
#  'JLWKWQYC',
#  '7QC6FOKW',
#  'XA184CMW',
#  'S0N7BYU3',
#  '6WOMHAJM',
#  'G1QGATKV',
#  'UAE5ZC7O',
#  '6XFVQI32',
#  'JUCNIG4H',
#  'OGD4MDJ9',
#  '4NGBUZWJ',
#  'EFG5DGV5',
#  '82MM4H33',
#  '14PM641K',
#  'DSBGHOPN',
#  '1YSOZLHF',
#  'E8RP9FRW',
#  '787IRG9Q',
#  '0TUS4NAC',
#  'FAJTQMUM',
#  'TWF0J0DF',
#  'ICMXZOVL',
#  'UQ14O415',
#  'IBEUTCSW',
#  'O3KC8QI8',
#  'BOJSLNDG',
#  'WALNFJ70',
#  'DASMR0EK',
#  'A76M0OOH',
#  'E1VKE2PH',
#  'SKY95DVG',
#  'V5OK4V5I',
#  'GJ4L5HHN',
#  '9R8JWY3J',
#  '0EOFVU05',
#  'HNHOPL7M',
#  'Y0NYI17R',
#  'R4F4RGAL',
#  'MNVMY83P',
#  '0ZHLQFGU',
#  '40DPY158',
#  'DP9E525R',
#  'DBDUMQQK',
#  'CNBN12RL',
#  'OXL0YWEE',
#  'ZOBJHMAF',
#  'KD6MB4AP',
#  '5CSSZJF4',
#  '0XG8TOJF',
#  'IIS0O91J',
#  '2LP5SUR5',
#  'PYZZ3IS6',
#  '5I4K5TQE',
#  'RV3LPOYP',
#  'A194RP0I',
#  '1HVNTEPV',
#  'LC85AQ1I',
#  'TBV972NP',
#  'EJMX0EIJ',
#  'VR9NYBOV',
#  '3U25FK08',
#  'KV2OFRJT',
#  'CRLK4Z1P',
#  'OGENAT0L',
#  'F57JWIDF',
#  'ERFRHR3Z',
#  'J53D8EOL',
#  'LF8JZ3Q5',
#  'MRGBSMQ5',
#  'CBAV8ZJL',
#  'J32XDDAW',
#  'NN4DWBVN',
#  '6JXHEZYK',
#  'WDHNR2EI',
#  '4K750D6F',
#  '94GI0ZJ7',
#  'TODG6DEK',
#  'G0ECB8FS',
#  '1ZDDZD8B',
#  '96MZYUY0',
#  'EZVKSQ9C',
#  'RJYG004O',
#  'JZOKHHWN',
#  'EH6I67I0',
#  'JUUXF02Z',
#  'OT87JDWO',
#  'YHKT6YJ7',
#  'H78I3TAY',
#  '1ROC43JK',
#  'LPZLQL48',
#  'PYOFK7ZD',
#  'DWUXMAGZ',
#  '3KR50X38',
#  'Q3WLHRE9',
#  'IX7UEOAP',
#  'NQU62K1H',
#  'NAQKOU0T',
#  'I3V3GUAI',
#  'PN4VJDXY',
#  'K9D4DQ3R',
#  '9X6V79KE',
#  '6SN2RQJX',
#  'W1KLFNE4',
#  'NKPH3EFG',
#  'GD2OCW12',
#  '6XO4RYXK',
#  '18Y7GRPW',
#  '127ZPLXQ',
#  'U07C2HEG',
#  'RNTOJ78L',
#  'N07K7DR7',
#  'NLB4D5BQ',
#  'FCFDJIEZ',
#  'YZGDW4G1',
#  'G8AO5FA2',
#  '125VIRMX',
#  'LXXW3TRW',
#  '8KJ3H262',
#  '88POGNEL',
#  'UYP3NNU6',
#  'S1V8684Y',
#  'MOPWEMB5',
#  'L62MDI48',
#  '3ECHUPQY',
#  '3EL8D4WO',
#  'VOAN1NXG',
#  'ALW92XQL',
#  'TJ6ZA1M3',
#  'FKAFO8O9',
#  '1XBC7M9F',
#  '8IXBS90G',
#  '2X45BEOS',
#  'EQ8X0QTL',
#  '5QD53WHF',
#  'K5CWSFCW',
#  '79EABK3X',
#  '2DKO9X1T',
#  'IBDEQVBN',
#  'QZ3VV4C1',
#  '62AK8UWX',
#  '5QM4ORNT',
#  '4H2QMS78',
#  'S91N9YBL',
#  '44H0FJMH',
#  'N5AZLQZR',
#  '4T295XQL',
#  'YFS5KLJJ',
#  'S8GLKDB9',
#  'SQLYCFGV',
#  'EUG019AS',
#  'IE7VQ5BA',
#  '01QKN578',
#  'M0JKP0HT',
#  'ZC3KKSUK',
#  '3X8VLQ5G',
#  'EZLXL6GL',
#  'R8PEL8V8',
#  'L1R32S8H',
#  'J7N8J8NM',
#  'TO7PGVP1',
#  'A051G1B4',
#  'NMDMM5YJ',
#  'LWPJEV3U',
#  'I93ZFHEM',
#  'B2VJCVBB',
#  'F90O03ZH',
#  'PC78RLUX',
#  'X6GL64T5',
#  'OWM3BPGW',
#  'RP5PS9A5',
#  'AI76U58A',
#  'KFPM2LJW',
#  'F2PW7WP2',
#  'GK8YD2XW',
#  'U4LRR9E9',
#  'B00UMAV4',
#  'C8TV7R8A',
#  '9N55D1AH',
#  '2VCDVCIZ',
#  'WI4PODA2',
#  'VF1V41RI',
#  '1B4L7TNG',
#  'MZAN11FT',
#  '0U3WVJO0',
#  '0IO00FNS',
#  '8S6TNXYB',
#  'PMMW9JX3',
#  'MOLGOSGE',
#  'FA1VHZSV',
#  'PXQEX039',
#  'RX56S6G3',
#  'G4F8W039',
#  '4T31MWVO',
#  '2HT2R2GY',
#  '83XN082U',
#  'J21W3WIW',
#  '52UPJFYI',
#  'QOL51JIB',
#  '13GM5I6M',
#  '93AGN8A6',
#  'J7UNJFJL',
#  'A4H5ESTU',
#  '8EZ04VQB',
#  '4501T63I',
#  '9IA34L8S',
#  'FPNGEJRC',
#  'S33WRL0Y',
#  'Q7IRUJK7',
#  'DTZPYISJ',
#  'Y9HWSG8Z',
#  '5T8Q2YID',
#  'JOQCXC9Z',
#  'AP7PCLAZ',
#  'BIE471SO',
#  'UA8AWDG4',
#  'BTT6YAVZ',
#  'FZDRB789',
#  'PC1NUL8Q',
#  'O7UUAK3Y',
#  'TLOHEQ18',
#  'F1X5ZJ7V',
#  'IF7MJ88P',
#  '06B7XWPC',
#  '12MQ3WM8',
#  '91M6FY8S',
#  '0LNZRNEU',
#  'NKOKUS7D',
#  'NF6GCTMV',
#  'I4UCA7CU',
#  'EWDOBEM6',
#  '1LI7ETNZ',
#  'N36DEZBR',
#  '77ZECYVJ',
#  'IRB461Y7',
#  'NM2Q3CGW',
#  'OEEUEIPJ',
#  '5E14LG51',
#  'TIAGZQ54',
#  'QM6VR1H5',
#  'QR2BDRAI',
#  'Z75ND4JF',
#  'CRX91A45',
#  'ZOQ8RC86',
#  'SV4SOO2K',
#  'ITHR5WLF',
#  'CGWJ1WHI',
#  '279625VN',
#  'M16D8PYH',
#  'RK52YU8S',
#  'E8EY51IC',
#  'HG07LMHI',
#  'VPXW8RJS',
#  '85XNDIK1',
#  '2U54WYQ1',
#  'VCA1WAB0',
#  'T7T1YIM7',
#  'MXNVX2AM',
#  '1G866GH4',
#  'WDG0B1IR',
#  'Q5CABPMO',
#  'HHBA93J5',
#  'R0W6A9BG',
#  'P5EGQ0HI',
#  'L1EJIE5L',
#  'S3XI6YB3',
#  'BBC3JB3H',
#  '4JHY98UG',
#  '7XVLKX8G',
#  'G39V1X3G',
#  'OX4P78HP',
#  '72LNJRY9',
#  '8C2WG2FB',
#  'L0345WKB',
#  'S24L8LVR',
#  'JXWXEJXE',
#  'W2JCRPLX',
#  'EQCD7G7Q',
#  '1M2I2NXQ',
#  'XYNTWPN1',
#  '54EGR0AD',
#  'VT5Y73GX',
#  '8O9V7UOZ',
#  'GIIC5H9X',
#  '9WMU7YHD',
#  '8BQMFR86',
#  'DDCC6ZPK',
#  'YMGWLEHY',
#  'FKS9MVF6',
#  '6Q67ZUJ1',
#  'HF8ABDF6',
#  'Y6UBZM6P',
#  'SIRC44NM',
#  '7S6SHJJG',
#  'ZE84UHHB',
#  '2R3ZA84D',
#  'LTTYTAXA',
#  'RIW4VWBW',
#  'ZWFPD71J',
#  'T5C527Z9',
#  'XC4LTIEO',
#  'AEBF9M5T',
#  'DWUD4S0P',
#  'MCE5DKD1',
#  'EV46ES18',
#  'ID3IJHUS',
#  'YBJ72HKE',
#  'RW39Y63V',
#  '5DEO8EDS',
#  '8LW65NDL',
#  'CJ2ON1LV',
#  '4I8X7EMW',
#  'WPXAMXD2',
#  'A4BBDK82',
#  'LMOAYCUK',
#  '4XCJP60W',
#  'CDKX2A19',
#  '344I60EI',
#  'YI30GSB5',
#  '0IYQX303',
#  '6IMUQYMN',
#  'N9GAZ6B6',
#  '8O3IYWSM',
#  'R3OR0J5C',
#  'VCSHYIU8',
#  '0I6U3MQ6',
#  'RXV4UXRE',
#  '5AKGNKX1',
#  'KNLMLTJH',
#  'WRUG19FZ',
#  'UQQE9ILV',
#  'G9GH5KV5',
#  'H06UZJH8',
#  'K1RXVUG9',
#  '1QT3STIA',
#  '070M5M6X',
#  'DFTR2O9K',
#  'W8CXDBQN',
#  'S9MECO24',
#  'EJSFO67U',
#  'VKT0UN11',
#  'SKTD4GGU',
#  'JIACLB24',
#  'SNAPG5KC',
#  '561707V4',
#  'J28ZRO9G',
#  '5VYJCJAE',
#  'BTUG5VDL',
#  'KZ8Q0AFX',
#  'CT3HBBI2',
#  'AOOFHH6F',
#  '5U9Y1P87',
#  'J0Y91LUA',
#  'YBRZQFEO',
#  'PHR8KB1Y',
#  'GR2X90DZ',
#  'TBZMXKH4',
#  'WNXZ1FGS',
#  'S3W6Q07M',
#  'K64TY8LU',
#  '6389JY2H',
#  'SZ81H1PM',
#  'M842E8JB',
#  'JRJ7DBW5',
#  'N9C0OCYY',
#  '0OESOJNN',
#  'R7XZAIWS',
#  'FFO5WOHT',
#  'XHHJ48MJ',
#  'YAR5GGA4',
#  'NOVPMLOV',
#  'UPHN2I1Q',
#  'NN9R2Y4W',
#  '977FJ9QQ',
#  'DZ57QIQN',
#  'A6Y1V5Z0',
#  'NU8LWEWU',
#  'PFHS80CR',
#  'OZ5S8NCK',
#  '904203D6',
#  'Z0TSV030',
#  '8C4QM1X6',
#  'NOPI41RP',
#  '2536CW3V',
#  'AC5YXLIR',
#  'HSGJKH6U',
#  '4TZF9N1D',
#  'HNKZ2IC6',
#  'BB6TCH8B',
#  'IMTPZV7J',
#  'A4JROIDO',
#  '6NXY7144',
#  'KBKHKULU',
#  'INMJIFTF',
#  'FUVQ5UKB',
#  'O462ARMZ',
#  '6DCKCXDC',
#  'QVF0JRM5',
#  '7QGG2LO3',
#  'Y6HNPIIT',
#  'IBKRO1AN',
#  '3TDWLPMV',
#  'JN1ZFD18',
#  'ZE7ILYKB',
#  'SRFVQ0HG',
#  'D7H1EGS9',
#  '1DDW2GQW',
#  'PMEENWD5',
#  'WPGTHV8V',
#  'Z1WLLL1H',
#  '6GNJMYMO',
#  'GWAT8UWK',
#  'ETZKANFZ',
#  'IZD69C5Q',
#  'QFU565JJ',
#  'Z5BCBTAO',
#  '2KKRRM1G',
#  'RLUGVSNV',
#  'ZKSJ1DOK',
#  'K8RQWTP4',
#  'RSZC6BMW',
#  'O7YNBRX0',
#  'PK1PS0KR',
#  'AAYV8GV4',
#  'EDEBWIOX',
#  'VAH6Y3F6',
#  '4U431MNA',
#  '5HKAT5GS',
#  'F5VDTC4M',
#  'UO4KXDBC',
#  'TBIW957T',
#  'MSEIIH95',
#  'RPONINLM',
#  'V4324HG4',
#  'N852D2Z8',
#  'CF1CSNPX',
#  'NOXNFJ2L',
#  'F569KUVC',
#  'PKDJTR06',
#  'VYPYVO8V',
#  '3LJAJVHR',
#  'NN6CSUWT',
#  'X69POZIN',
#  '4FAEDB16',
#  'CPGCT81C',
#  'TK9T01QM',
#  'P13DDOTM',
#  '1PN7TVPX',
#  '9ZKORPL2',
#  '1D54L027',
#  '1ZCOKNNI',
#  'BVYMJ6TD',
#  'W5ADQ9SH',
#  'VXX8GJGY',
#  'ES9L0DXE',
#  'AANB25RH',
#  '36PTGLTW',
#  '6WTNSL1T',
#  'PV1DISEC',
#  'S6BG03TB',
#  '2YOW2BI0',
#  'IQ9KYZCG',
#  'AWDOKG69',
#  'C4AFMVFM',
#  'WK6ERCGR',
#  '64DJ954O',
#  '84V18DBW',
#  'WFY0S4WW',
#  'HA1KXAIS',
#  'CENVLTFH',
#  'EAYD98X2',
#  'YR4W59KS',
#  'SNFW1FD7',
#  '4NGSQODD',
#  '2EOF1QCY',
#  '5BE27MLY',
#  'O5O4ZAAC',
#  'YBAKNQ8Z',
#  'N5UIZYIV',
#  'QY6HCHDH',
#  'CZ3XOD03',
#  'LQ44KCMI',
#  'WVJBVA61',
#  'MV9AO6WU',
#  'VS2G74XQ',
#  'Q37IWCG1',
#  'CUR03RXO',
#  '81APSLDP',
#  'RBXWRHBJ',
#  'G2GU9DYX',
#  'KBR253C0',
#  '379DUF2N',
#  '67IKZGGJ',
#  '05DTWSVC',
#  '2YQHHWJ3',
#  'ZW58VIDI',
#  'Q7IIF1IP',
#  'AALARPLH',
#  '8YIANRVX',
#  '5FFY13G5',
#  '01X8H9SO',
#  'VLADQZ43',
#  'N9VYMV3W',
#  'A7SA2L21',
#  '2FTB6A7I',
#  '7V9A9TXZ',
#  'HWDRCUYU',
#  'GFV4W89I',
#  '7A4AC5BC',
#  '3B6HWK65',
#  'A3BK99P6',
#  '9W7PFSNX',
#  'XYLNH45V',
#  'GVBWTDI3',
#  'NY21X16G',
#  'O5BC64NW',
#  '4DW2FDX4',
#  'A66X4Q2J',
#  'VFEV5XBS',
#  'IT9YW5RP',
#  '7IZ2GMYK',
#  'TTY0X4TG',
#  'L8D22SSW',
#  'ZDDZ64A2',
#  'RDJFZGM9',
#  '4563ENEB',
#  '4WP0VJAS',
#  '60UOBOEM',
#  'AJZB6F22',
#  'W4K39GNG',
#  'VN8LKQN3',
#  'IXOHJYRM',
#  'RMNHSNW9',
#  'QPFNQYMV',
#  'D77SFTS4',
#  'ZHY9C8OO',
#  'WRBWZRFD',
#  '031BBF1I',
#  'H2MC2E7K',
#  'O11S2R63',
#  'G13DD850',
#  'WZU2OHYU',
#  'HVODWXRO',
#  'N3JIVUNY',
#  'RGCH6CUF',
#  'JX7WZ9UP',
#  'FDCEBWRI',
#  'ZL6TJDPG',
#  'DWBSHB8M',
#  '0AJ6LTZ0',
#  'SVMB8M7E',
#  '6AWEAWCM',
#  '4Q4NBPD6',
#  'K8VSDOP8',
#  'YNP9PI1X',
#  '3XVY4LEU',
#  'OCGXWE8H',
#  '8K1OGB0R',
#  'RTKUPEX7',
#  'QQDO45YR',
#  'USVLKDF4',
#  'HT25XIAV',
#  '88KUDE6J',
#  'AOOD3MWW',
#  'JCPQZ2SN',
#  'HZIU2NOT',
#  'RZ2PUH86',
#  'GLVSDQQT',
#  '107BPCAS',
#  'OCLEO3CD',
#  'FTVCNH87',
#  'GQCRMEIL',
#  'UK2JIE61',
#  'YM8DBAFV',
#  'AEDL7EC6',
#  'OV5X3O5I',
#  'MMWX1A4H',
#  'LSVMMUJ0',
#  'RP7KA6HS',
#  '97KFQSX1',
#  '08APB75Q',
#  'P9PFSLS6',
#  '6RL97BR9',
#  'TPVFA5B8',
#  'FHLOUD3V',
#  '4E01ALB0',
#  'E4THD359',
#  'K4HVGBVH',
#  '6VIK2VX8',
#  '30R81VZX',
#  'XDLQ71X4',
#  'TH9RV79M',
#  'L33YUX9V',
#  'QT7LRWTN',
#  'Q1JKHY7H',
#  'BY0O646G',
#  '5831YZMT',
#  '7VOW7BUJ',
#  '2J5E145N',
#  'AZUBCO7L',
#  'FOWAY95L',
#  'YFB7Y92U',
#  'KGZL60NI',
#  'SRZMNS79',
#  'S6645YWA',
#  'B5A1BERF',
#  '0XMB83YO',
#  '4TEO0LE1',
#  'IEAPJ5X1',
#  '5P82H5AA',
#  'BN8UTT8O',
#  'V751HK8R',
#  'H4TBCR80',
#  'QWL218JV',
#  'L2S4T3VA',
#  'AF8NG5JC',
#  'IVJP36UT',
#  '12M4HB7G',
#  '1XVTUE5J',
#  '3VKO28KR',
#  '9A9E1KPG',
#  '5IES0B4B',
#  'HUFYU0AT',
#  'GMI6XZ4O',
#  'TF19VML9',
#  'YOQCQ4UO',
#  'KOZTDBJ5',
#  'ZHXIDZNI',
#  '8NMPO9K3',
#  'PU7GV4MK',
#  'RCQDGE4W',
#  'ZT832XIR',
#  'I995O4XJ',
#  'EOXZGSX9',
#  'PW5OGY78',
#  'NJCSG7MX',
#  'ZYRF768H',
#  '5Q8BQ64R',
#  'ZNNBFAKF',
#  'L47EPGVT',
#  '9GENDMWA',
#  'DHACLHPS',
#  'GKLE0CDI',
#  'E9DJS1D8',
#  '22ZJM20V',
#  'C47Z92AG',
#  'XT9YNOV2',
#  'TMZQX7F8',
#  '5JHSTFEZ',
#  'BAOSO1I2',
#  'IZDF2RTL',
#  'F61DLVRS',
#  '80F0J70G',
#  'S9W53L4L',
#  '12OQKSVK',
#  'VC94R5H8',
#  'XTKIX6I4',
#  '5P3NH791',
#  'MSE1UXKU',
#  'HM334UL2',
#  'L4124UJG',
#  'DR2QE1RW',
#  'FD8YL177',
#  'X3ZSQCH8',
#  'UU21EYFN',
#  'OBDRD0AD',
#  'NSGEM06J',
#  'QSQ42Q6M',
#  'PCBA3KAV',
#  'ZBBMGEV4',
#  'TYSORYA9',
#  'ULVXOPG3',
#  '5BXUKFPR',
#  'G0R305KO',
#  'ZDZGCWX7',
#  'PQJZ5Z3R',
#  '8AJG1YLJ',
#  '7KXTF2Q6',
#  'WZVE1NTM',
#  'M6UEZLOQ',
#  'D6T5MM04',
#  '5RNWV17L',
#  '9GCJGVY7',
#  '5QBQMEY5',
#  '9JKVM4BK',
#  '14PBBHSE',
#  'P1KS5YFX',
#  '7R4VL3Q8',
#  '3MNZF5ZK',
#  '52SANIGE',
#  '73SY9EU8',
#  'HVM656P3',
#  'LXM6CTMS',
#  'U2SW8DT1',
#  'VXMFL425',
#  'XMH4CH4Q',
#  'UNLIS3RY',
#  'GVFQXZLL',
#  'E887HZT1',
#  'CGJ7NRZH',
#  'NRYC7T45',
#  'ZVR3I3F0',
#  '2TKQ8B78',
#  'OZ5O64KJ',
#  'WXCW16QT',
#  'UCXCUP1U',
#  'SWJ9OOZU',
#  '9ERRIZKG',
#  'CKLYIFLY',
#  '6VDLCBYU',
#  'XYBPUC2H',
#  'B06D1F9M',
#  'OZ761BUJ',
#  'I3MC9XZC',
#  'L5T2HKKO',
#  '6CEEGQ8I',
#  'P2LY9NFN',
#  '94GCWI08',
#  'GUMQTC3J',
#  'U64RT0UF',
#  'RWGSCFHR',
#  'GEBVQH17',
#  '3OVJXUSB',
#  'KQPY8LLI',
#  'DC7COE9W',
#  '3LED0EK3',
#  'SCS5H8V1',
#  '81MXE1H7',
#  'G4MKT3AE',
#  'GQ125FX0',
#  'JO52QXJ0',
#  'PQ2VF873',
#  'N6H58J55',
#  'W24IDMVV',
#  'WR6Q2X53',
#  '8O1WNJBA',
#  'X1LAD57Y',
#  'E2NXQUWO',
#  'MEZLJGRB',
#  'M1QKPX6R',
#  'X6LO8WPD',
#  'JQA8H6M5',
#  '92G1TO7L',
#  'S8WV5MUC',
#  'FW2XJG9S',
#  'R7JI95HZ',
#  'SVCKI631',
#  'VJ5QGP8Z',
#  'CVKLHZEO',
#  '8KJZJFJ1',
#  'W560QFJL',
#  'TA3PW6ZQ',
#  '2DVE0XCM',
#  'L3UMWAX7',
#  'R2W96FGX',
#  'VOTOT8MK',
#  'Y3ULGUD8',
#  '7350YGG4',
#  '2J16RN99',
#  'BRQRF65L',
#  'LB6XW39X',
#  'WS9CXY7E',
#  'CK0MDHHM',
#  'KM1D04JS',
#  'RNUH1SI8',
#  'BNY8MJ6L',
#  'INBGKE14',
#  'D54HETSI',
#  'JOQQZ5RH',
#  '90V75MDV',
#  'LIIBOUUQ',
#  '5KK2SSSB',
#  'UDYSM42B',
#  'V3HVIJLL',
#  'F835LA4P',
#  '75Q82XU7',
#  'AMNKCM1H',
#  '2U6QQHCC',
#  'MMKMJ0WC',
#  'CZIXINO2',
#  'HV7Y6184',
#  'KIHC1QJQ',
#  'VBWQO6BM',
#  'LTZCN1RA',
#  '84LN84VM',
#  'YO32O3T9',
#  'MU7JWTP6',
#  '8638OV6W',
#  'TTJXSO57',
#  'K4VP5HK4',
#  '10R46CSK',
#  'VBA34LWX',
#  'DLJN7WG0',
#  'FJCCTOPN',
#  'LR6USOHL',
#  '5VAV2TUY',
#  'HTD2ME9C',
#  'GHUCMUPL',
#  '1LKY3B4X',
#  '7Y5E0RDL',
#  '9HRMW8SL',
#  'BEQIZZ7W',
#  '44F8ZE41',
#  'YJIH415V',
#  'K3DQJ796',
#  '6QF3D2RI',
#  'G9565UWZ',
#  'RFKIN7FG',
#  'WJQ8VD51',
#  '2BWZLXZ8',
#  '1WHXI2RW',
#  'G5JP0G7Q',
#  '2QHRL8CW',
#  'RFYAI0WA',
#  'WH0DJCGL',
#  'LCW83256',
#  'RVH3UUKY',
#  'IHFM8QXN',
#  'QCY951QA',
#  'CG9VXPV1',
#  '09BVA55J',
#  '2R9HXKXT',
#  'JLK8KCNN',
#  'SZQUBIMH',
#  '8ZYVKQ27',
#  '25A51PWG',
#  '4B4XCPHT',
#  '5JFOA4XC',
#  'N5FOEJZ9',
#  'CYWZJ2AI',
#  'QTNPGKJ7',
#  'EBRWSMI0',
#  '4PKHDQOQ',
#  '3Y9SB2QK',
#  '5MZ0O77T',
#  '2EILEDKF',
#  'J4NX9TK5',
#  'Y7N97FW8',
#  '0IO43YMS',
#  '5ITSLO0E',
#  '6HG76L6U',
#  'QGW0TI1U',
#  'WJC5J533',
#  '9SLINQY5',
#  '1GIP77EP',
#  'XGLMCTLG',
#  'X6RLT30X',
#  'IVT0S1N1',
#  'NOLCZMV6',
#  'JEPGSQC9',
#  ...]

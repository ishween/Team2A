# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("merged_df.csv")

# %%
df['deal_stage'].unique()
# Out:
# array(['Won', 'Engaging', 'Lost', 'Prospecting'], dtype=object)

# %%
counts = df['deal_stage'].value_counts()
plt.figure(figsize=(10,6))
plt.title('Deal Stages')
counts.plot(kind='bar')
# Out:
# <Axes: title={'center': 'Deal Stages'}, xlabel='deal_stage'>

# %%
plt.bar(df["deal_stage"], df["deal_value"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Sai\anaconda3\envs\cs171\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'deal_value'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plt.bar(df["deal_stage"], df["deal_value"])
#
# File c:\Users\Sai\anaconda3\envs\cs171\Lib\site-packages\pandas\core\frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File c:\Users\Sai\anaconda3\envs\cs171\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'deal_value'

# %%
df.describe()
# Out:
#         close_value   sales_price  year_established       revenue  \
# count   6711.000000   8800.000000       7375.000000   7375.000000
# mean    1490.915512   2379.109659       1995.483661   2467.515536
# std     2320.670773   2629.243384          9.187126   2596.135671
# min        0.000000     55.000000       1979.000000      4.540000
# 25%        0.000000    550.000000       1988.000000    647.180000
# 50%      472.000000   1096.000000       1995.000000   1698.200000
# 75%     3225.000000   4821.000000       2002.000000   2952.730000
# max    30288.000000  26768.000000       2017.000000  11698.030000
#
#           employees
# count   7375.000000
# mean    5701.213424
# std     6816.683924
# min        9.000000
# 25%     1238.000000
# 50%     3492.000000
# 75%     7523.000000
# max    34288.000000

# %%
df.corr(numeric_only=True)
# Out:
#                   close_value  sales_price  year_established   revenue  \
# close_value          1.000000     0.679396         -0.025376  0.028136
# sales_price          0.679396     1.000000         -0.039430  0.051267
# year_established    -0.025376    -0.039430          1.000000 -0.475750
# revenue              0.028136     0.051267         -0.475750  1.000000
# employees            0.035061     0.052708         -0.464594  0.950034
#
#                   employees
# close_value        0.035061
# sales_price        0.052708
# year_established  -0.464594
# revenue            0.950034
# employees          1.000000

# %%
df
# Out:
#      opportunity_id        sales_agent         product  account   deal_stage  \
# 0          1C1I7A6R        Moses Frase  GTX Plus Basic  Cancity          Won
# 1          Z063OYW0    Darcel Schlecht         GTX Pro    Isdom          Won
# 2          EC4QE1BX    Darcel Schlecht      MG Special  Cancity          Won
# 3          MV1LWRNH        Moses Frase       GTX Basic  Codehow          Won
# 4          PE84CX4O          Zane Levy       GTX Basic   Hatfan          Won
# ...             ...                ...             ...      ...          ...
# 8795       9MIWFW5J  Versie Hillebrand     MG Advanced      NaN  Prospecting
# 8796       6SLKZ8FI  Versie Hillebrand     MG Advanced      NaN  Prospecting
# 8797       LIB4KUZJ  Versie Hillebrand     MG Advanced      NaN  Prospecting
# 8798       18IUIUK0  Versie Hillebrand     MG Advanced      NaN  Prospecting
# 8799       8I5ONXJX  Versie Hillebrand     MG Advanced      NaN  Prospecting
#
#      engage_date  close_date  close_value           manager regional_office  \
# 0     2016-10-20  2017-03-01       1054.0  Dustin Brinkmann         Central
# 1     2016-10-25  2017-03-11       4514.0     Melvin Marxen         Central
# 2     2016-10-25  2017-03-07         50.0     Melvin Marxen         Central
# 3     2016-10-25  2017-03-09        588.0  Dustin Brinkmann         Central
# 4     2016-10-25  2017-03-02        517.0     Summer Sewald            West
# ...          ...         ...          ...               ...             ...
# 8795         NaN         NaN          NaN  Dustin Brinkmann         Central
# 8796         NaN         NaN          NaN  Dustin Brinkmann         Central
# 8797         NaN         NaN          NaN  Dustin Brinkmann         Central
# 8798         NaN         NaN          NaN  Dustin Brinkmann         Central
# 8799         NaN         NaN          NaN  Dustin Brinkmann         Central
#
#      series  sales_price    sector  year_established  revenue  employees  \
# 0       GTX         1096    retail            2001.0   718.62     2448.0
# 1       GTX         4821   medical            2002.0  3178.24     4540.0
# 2        MG           55    retail            2001.0   718.62     2448.0
# 3       GTX          550  software            1998.0  2714.90     2641.0
# 4       GTX          550  services            1982.0   792.46     1299.0
# ...     ...          ...       ...               ...      ...        ...
# 8795     MG         3393       NaN               NaN      NaN        NaN
# 8796     MG         3393       NaN               NaN      NaN        NaN
# 8797     MG         3393       NaN               NaN      NaN        NaN
# 8798     MG         3393       NaN               NaN      NaN        NaN
# 8799     MG         3393       NaN               NaN      NaN        NaN
#
#      office_location     subsidiary_of
# 0      United States               NaN
# 1      United States               NaN
# 2      United States               NaN
# 3      United States  Acme Corporation
# 4      United States               NaN
# ...              ...               ...
# 8795             NaN               NaN
# 8796             NaN               NaN
# 8797             NaN               NaN
# 8798             NaN               NaN
# 8799             NaN               NaN
#
# [8800 rows x 18 columns]
